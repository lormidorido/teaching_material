// %% [markdown]
// # Unit 10 Part 1: What is Sorting?
//
// ## Paul Curzon
//
// ## Interactive Programming Exercises
//
// ### Learning Outcomes
// - explain what is meant by sorting data into order
// - explain and use the operators that define the order that two values would come in a sorted order.
//
// *This notebook looks at code fragments. After completing these exercises you MUST then go on to write full programs - see the programming exercises in the workbook.*
//
// *Answers to exercises are given at the end*
//
// **Always read the answers to exercises and compare them to your own. There are important things to learn from the answers.**
//
// <span style="color: red;"> It is a really good idea to add your own notes throughout this notebook to reinforce what you have learnt and highlight important points. Click on the + in the toolbar above to make a new note area, and change it from Code to Markdown in the dropdown menu above if your note is not executable code. You may also want to highlight your notes in red as here, so they stand out. You change colours using span like this: </span>
// ```
// <span style="color: red;">THE TEXT TO COLOUR RED</span>
// ```

// %% [markdown]
// ## Introduction: What is sorting?
// How do you put things in to order? You need a sort algorithm. It is an organised way that guarantees to put data into order. Bubble sort is one very simple way of sorting data. Here we are going to focus on something more fundamental - what do we mean by the **order** we are sorting things in to as well as what it actually means to sort different types of value into order.
//
// There are many meanings of the verb ‘to sort’. It could mean to fix things, it could mean to put things in to groups. To a computer scientist ‘sorting’ means something very specific. It means taking a series of pieces of data and putting them into a set order, one after the other, either from smallest to largest or from largest to smallest.
//
// For example, sorting numbers means putting them in to numerical order. If we are given the numbers:
// 5, 7, 2, 99, 4
// then after sorting them in to ascending order we have the list:
// 2, 4, 5, 7, 99
// If we were to sort them into descending order then, instead, we would get the list:
// 99, 7, 5, 4, 2

// %% [markdown]
// ### Exercise 1<a id="Exercise1"></a>
//
// Put the following integers in to **ascending** order
//
// {7, 3 , 9, 12, -45}

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution1)

// %% [markdown]
// ### Exercise 2<a id="Exercise2"></a>
//
// Put the following integers in to **descending** order
//
// {16, 24 , 2, -13, 99}

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution2)

// %% [markdown]
// In both the above cases you sorted the data. When you did so you probably used some informal algorithm, such as first looking through the whole list for the smallest value and putting it into place, then looking for the next smallest, and so on, creating a new list as you went:
//
// Scan the list looking for the smallest (-45) and move it to a new list
//
// {-45}
//
// Scan the list looking for the smallest (3) and move it
//
// {-45, 3}
//
// {-45, 3, 7}
//
// {-45, 3, 7, 9}
//
// {-45, 3, 7, 9, 12}
//
// That is a perfectly good algorithm for sorting, though it assumes you have somewhere else to build up the answer. It is also quite slow (imagine sorting a million items that way).
//
// All sort algorithms including the above one relies on you being able to comparing pairs of values. In the above we had to repeatedly compare the smallest value found so far with each remaining element in the list of numbers to see if there was one smaller. We are relying on the "less than" operator (<). In fact having such an operation defines what we mean by sorting to define the order.
//
// When sorting in to ascending order, the order is defined by the less than operator. To sort into descending order we do exactly the same, but comparing elements using the greater than operator instead.

// %% [markdown]
// ## Sorting Characters

// %% [markdown]
// ### Exercise 3<a id="Exercise3"></a>
//
// Put the following characters in to **ascending** (ie alphabetical) order
//
// {'z', 'a' , 'p', 'c', 'd'}

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution3)

// %% [markdown]
// Again we can use exactly the same algorithm to sort the data, just with a different operator to give the order. Here by ascending order for characters we meant alphabetical order. In Java we use the same symbols to mean less than and greater than for characters. In fact what they are doing is comparing the ASCII code order of the characters - the underlying number used to represent the character. This orders all characters including lower case, upper case, punctuation,

// %% [markdown]
// ### Exercise 4<a id="Exercise3"></a>
//
// Read the code below and predict what it will print, then swap the characters from 'a' and 'b' to other characters to experiment with what characters come earlier than others in the order that the > operator determines.

// %% [markdown]
// **Write your answer here**

// %%
char firstCharacter = 'a';
char secondCharacter = 'b';

if(firstCharacter > secondCharacter)
    System.out.println(firstCharacter + " is bigger than " + secondCharacter);
else
    System.out.println(secondCharacter + " is bigger than "+ firstCharacter);

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution4)

// %% [markdown]
// ## Ordering (and so Sorting) Strings
//
// What about sorting Strings? We have a natural ordering - alphabetical ordering to use but what exactly does that mean? To work out the alphabetical order of two Strings, we just use the order of characters, but apply it to each letter in turn starting from the first. As soon as we find letters in corresponding positions that are different, then that tells us the order of the strings.
//
// So comparing cat

// %% [markdown]
// ### Exercise 5<a id="Exercise5"></a>
//
// Put the following characters in to **ascending** (ie alphabetical) order
//
// {"dog", "ant", "cat", "bat", "cow", "catty"}

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution5)

// %% [markdown]
// To work out the alphabetical order of two Strings, we just use the same ordering as for  characters, but apply it to each letter in turn starting from the first. As soon as we find letters in corresponding positions that are different, then that tells us the order of the strings.
//
// Comparing "cat" and "ant" then "ant" comes first as comparing the first letters 'a' is before 'c'. We do not need to look at any other letters at all to know that "ant" comes first.
//
// Comparing "cat" and "cow", we find the first letters are the same, so we need to move on to check the second letters. They are different and 'a' comes before 'o' so "cat" comes before "cow". This time we need to check the first two letters but not the third.
//
// If we were to compare "cat" and "car" we would need to check all three letters to see that "cat" comes first.
//
// What about comparing "cat" and "catty". The algorithm says check letters in turn but when you run out of letters, with all the same up to that point, then the shorter comes first.

// %% [markdown]
// ### Exercise 6<a id="Exercise6"></a>
//
// Complete the following method so that it compares Strings correctly, according to alphabetical order. You need to replace each of the four ??? with an appropriate true or false value.
//
// Edit the following for your answer.

// %%
public boolean lessThanString(String s1, String s2)
{
    int shortestLength;
    int length1 = s1.length();
    int length2 = s2.length();
    
    // First find the length of the shortest of the two strings
    if (length1 < length2)
        shortestLength = length1;
    else
        shortestLength = length2;
    
    // Then check the two Strings character by character up to that point
    for (int i = 0; i< shortestLength; i++)
    {
        if (s1.charAt(i) < s2.charAt(i))
            return ??? ;                              // return either true or false here
        else if (s1.charAt(i) > s2.charAt(i))
            return ??? ;                         // return either true or false here
    }
    
    // if we get to this point they or the same or one is shorter than the other
    if (length1 == length2)
        return ; // They are the same so not less
    else if (length1 < length2)
        return ??? ;  // return either true or false here
    else
        return ??? ; // return either true or false here
}

// %% [markdown]
// Test your completed method using the following 4 test calls. Which should give answers
//
// false
//
// true
//
// true
//
// false

// %%
System.out.println(lessThanString("cat","ant"));
System.out.println(lessThanString("cat","cow"));
System.out.println(lessThanString("cat","catty"));
System.out.println(lessThanString("cat","cat"));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution6)

// %% [markdown]
// In fact there is already a method (compareTo) to compare Strings in the String library, however it is coded to return an integer rather than true or false. It returns a 0 if the two strings are equal, a negative number if the first is smaller and a positive if the first is larger.

// %% [markdown]
// ### Exercise 7<a id="Exercise7"></a>
//
// Predict whether each of the following calls will print a positive number, a negative number or 0, then run the code to see if you were right.

// %%
System.out.println("cat".compareTo("ant"));
System.out.println("cat".compareTo("cow"));
System.out.println("cat".compareTo("catty"));
System.out.println("cat".compareTo("cat"));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution7)

// %% [markdown]
// Complete the following version of our lessThanString method using compareTo to do the comparison.

// %% [markdown]
// ### Exercise 8<a id="Exercise8"></a>
//
// Complete the following version of our lessThanString method using compareTo to do the comparison. Test it using the given test calls.

// %%
public boolean lessThanString2(String s1, String s2)
{
    if (s1.compareTo(s2) == 0)
        return false;
    else if (???)
        return true;
    else
        return false;
}

// %%
System.out.println(lessThanString2("cat","ant"));
System.out.println(lessThanString2("cat","cow"));
System.out.println(lessThanString2("cat","catty"));
System.out.println(lessThanString2("cat","cat"));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution8)

// %% [markdown]
// ### Exercise 9<a id="Exercise9"></a>
//
// Write a greaterThanString method using compareTo to do the comparison to determine if its first argument is greater than the second or not. Test it using the given test calls.
//
// **Write your answer in the box below.**
//
// Then test it using the given test calls. They should print
//
// true
//
// false
//
// false
//
// false

// %%
System.out.println(greaterThanString("cat","ant"));
System.out.println(greaterThanString("cat","cow"));
System.out.println(greaterThanString("cat","catty"));
System.out.println(greaterThanString("cat","cat"));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution9)

// %% [markdown]
// ## Ordering Records
//
// What about sorting Records? We just need to write a similar method that compares pairs of records.
//
// We can write different methods that sort on different fields depending on what matters. For example, the following record stores the medal haul of a country in the Olympics. We can give two different orders, one to sort an array of such records alphabetically by country, the other to sort it numerically by medal total. We could also provide methods for each that sort in ascending or descending order.

// %%
class MedalCount
{
    String country;
    int medalTotal;
}

// %% [markdown]
// Below is a method that compares a pair of such records alphabetically by country that uses the lessThanString2 method for comparing Strings to decide the order.

// %%
public boolean lessThanMedalCountCountry(MedalCount mc1, MedalCount mc2)
{
    if ( lessThanString2(mc1.country, mc2.country) )
        return true;
    else
        return false;
}

// %% [markdown]
// We can test it using the code below. Note if MedalCount was defined as an ADT then we would use appropriate create and accessor methods to access the fields. We do not here just to help novices better follow what is being done.

// %% [markdown]
// ### Exercise 10<a id="Exercise10"></a>
//
// Predict what the following test code will print. Then run it to see if you are right.
//
// **Write your answer below.**

// %%
MedalCount country1 = new MedalCount();
country1.country = "China";
country1.medalTotal = 88;

MedalCount country2 = new MedalCount();
country2.country = "USA";
country2.medalTotal = 113;

System.out.println(lessThanMedalCountCountry(country1, country2));
System.out.println(lessThanMedalCountCountry(country2, country1));
System.out.println(lessThanMedalCountCountry(country1, country1));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution10)

// %% [markdown]
// ### Exercise 11<a id="Exercise11"></a>
//
// Write a method greaterThanMedalCountMedalTotal that compares records by the number of medals rather than by country name and so as to order them in descending order if used to sort.
//
// **Write your answer in the box below.**
//
// Then test is using the given test code that should print
//
// false
//
// true
//
// false

// %%
public boolean greaterThanMedalCountMedalTotal(MedalCount mc1, MedalCount mc2)
{

}

// %%
System.out.println(greaterThanMedalCountMedalTotal(country1, country2));
System.out.println(greaterThanMedalCountMedalTotal(country2, country1));
System.out.println(greaterThanMedalCountMedalTotal(country1, country1));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution11)

// %% [markdown]
// The above two methods can therefore be used with the same sort algorithm (however it is coded) to order an Olympic medal table either alphabetically in order of country name, or numerically in order of medal total in descending order so the country with the most medals is first in the table.

// %% [markdown]
// ## Ordering records based on multiple fields
//
// Now consider the following record for storing Olympic results for a country. Instead of an overall medal total, it stores the number gold, silver and bronze medals won.

// %%
class Medals
{
    String country;
    int gold;
    int silver;
    int bronze;
}

// %% [markdown]
// ### Exercise 12<a id="Exercise12"></a>
//
// In many countries including Great Britain (though not all) Olympic medal tables are not ordered by the total medals but first of all by the number of golds, then by the number of silvers (if two countries have the same number of golds) then by the number of bronze medals (if two countries have the same number of gold medals and the same number of silver medals).
//
// Write a comparison method that orders Medals records in this way. Test it using the given test code which should print
//
// false
//
// true
//
// true
//
// false
//
// **Write your answer in the box below.**

// %%
Medals country1 = new Medals();
country1.country = "China";
country1.gold = 38;
country1.silver = 32;
country1.bronze = 17;

Medals country2 = new Medals();
country2.country = "USA";
country2.gold = 39;
country2.silver = 41;
country2.bronze = 33;

Medals country3 = new Medals();
country3.country = "Mars";
country3.gold = 2;
country3.silver = 60;
country3.bronze = 12;

Medals country4 = new Medals();
country4.country = "Venus";
country4.gold = 2;
country4.silver = 15;
country4.bronze = 277;

System.out.println(greaterThanMedals(country1, country2));
System.out.println(greaterThanMedals(country1, country3));
System.out.println(greaterThanMedals(country1, country4));
System.out.println(greaterThanMedals(country1, country1));

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution12)

// %% [markdown]
// ### Exercise 13<a id="Exercise13"></a>
//
// Summarise the main points you have learned about sorting and operations for ordering values. Then read our summary in the answer section and compare it with your own.

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// ### What comes next
//
// *Once you have done the above exercises (and understand what it means to sort) you need to understand and be able to code bubblesort.*
//
// We have looked at what it means to sort and to determine which of a pair comes first. Before we get to being able to actually sort data (ie sort an array) into order, we need to know how to move data around in an array ie swap data. That will allow us to put pairs of data in order. We then need to be able to work out how to repeatedly swap pairs so that a whole array can be put into order pairs at a time.

// %% [markdown]
// ## Solutions
//
// ### Solution to Exercise 1<a id="Solution1"></a>

// %% [markdown]
// Ascending order means smallest to largest:
//
// {-45, 3, 7, 9, 12}

// %% [markdown]
// [Return to Exercise](#Exercise1)

// %% [markdown]
// ### Solution to Exercise 2<a id="Solution2"></a>

// %% [markdown]
// Descending order means largest to smallest:
//
// {-13, 2 , 16, 24, 99}

// %% [markdown]
// [Return to Exercise](#Exercise2)

// %% [markdown]
// ### Solution to Exercise 3<a id="Solution3"></a>

// %% [markdown]
// For characters we use alphabetical order:
//
// {'a', 'c' , 'd', 'p', 'z'}

// %% [markdown]
// [Return to Exercise](#Exercise3)

// %% [markdown]
// ### Solution to Exercise 4<a id="Solution4"></a>

// %% [markdown]
// It prints
//
// b is bigger than a
//
// The order of characters is given by the ASCII character codes (see for example https://en.wikipedia.org/wiki/ASCII which is just a way of representing characters as numbers or bit patterns)
// In the printable characters the SPACE character comes first then ! followed by more punctuation, the digits, more punctuation characters, upper case letters ...and then lower case. Run the following little bit of code prints all the characters in the order defined by the > operator for characters (which just compares their positions in this list)

// %%
for(int i = 32; i<=126; i++)
    System.out.println((char)i);

// %% [markdown]
// [Return to Exercise](#Exercise4)

// %% [markdown]
// ### Solution to Exercise 5<a id="Solution5"></a>

// %% [markdown]
// The order is
//
// {"ant", "bat", "cat", "catty", "cow", "dog"}

// %% [markdown]
// [Return to Exercise](#Exercise5)

// %% [markdown]
// ### Solution to Exercise 6<a id="Solution6"></a>

// %%
public boolean lessThanString(String s1, String s2)
{
    int shortestLength;
    int length1 = s1.length();
    int length2 = s2.length();
    
    // First find the length of the shortest of the two strings
    if (length1 < length2)
        
        shortestLength = length1;
    else
        shortestLength = length2;
    
    // Then check them character by character up to that point
    for (int i = 0; i< shortestLength; i++)
    {
        if (s1.charAt(i) < s2.charAt(i))
            return true;
        else if (s1.charAt(i) > s2.charAt(i))
            return false;
    }
    
    // if we get to this point they or the same or one is shorter than the other
    if (length1 == length2)
        return false; // They are the same so not less
    else if (length1 < length2)
        return true; // s1 is shortest so comes first
    else
        return false; // s2 is shortest so comes first
}

// %% [markdown]
// [Return to Exercise](#Exercise6)

// %% [markdown]
// ### Solution to Exercise 7<a id="Solution7"></a>
//
// Positive number (as "cat" comes after "ant" alphabetically)
//
// Negative number (as "cat" comes before "cow" alphabetically)
//
// Negative number  (as "cat" comes before "catty" alphabetically)
//
// 0 (as the two strings are the same)

// %% [markdown]
// [Return to Exercise](#Exercise7)

// %%
public boolean lessThanString2(String s1, String s2)
{
    if (s1.compareTo(s2) == 0)
        return false;
    else if (s1.compareTo(s2) < 0)
        return true;
    else
        return false;
}

// %%
System.out.println(lessThanString2("cat","ant"));
System.out.println(lessThanString2("cat","cow"));
System.out.println(lessThanString2("cat","catty"));
System.out.println(lessThanString2("cat","cat"));

// %% [markdown]
// [Return to Exercise](#Exercise8)

// %% [markdown]
// ### Solution to Exercise 9<a id="Solution9"></a>

// %%
public boolean greaterThanString(String s1, String s2)
{
    if (s1.compareTo(s2) == 0)
        return false;
    else if (s1.compareTo(s2) > 0)
        return true;
    else
        return false;
}

// %%
System.out.println(greaterThanString("cat","ant"));
System.out.println(greaterThanString("cat","cow"));
System.out.println(greaterThanString("cat","catty"));
System.out.println(greaterThanString("cat","cat"));

// %% [markdown]
// [Return to Exercise](#Exercise9)

// %% [markdown]
// ### Solution to Exercise 10<a id="Solution10"></a>
//
// It prints:
//
// true
//
// false
//
// false
//
// As it is comparing country names, China comes before USA in alphabetical order, so it is true that the record for country1 is less than the record for country2 using this ordering. Similarly it is false that USA comes before China so false that the record for country2 is less than the record for country1 using this ordering. It is also false that the record for China comes before the record for China.

// %% [markdown]
// [Return to Exercise](#Exercise10)

// %% [markdown]
// ### Solution to Exercise 11<a id="Solution11"></a>
// We now need to extract the values to compare from the medalTotal fields AND use the > operator as the basis of the ordering as we want the largest number to come first in the ordering.

// %%
public boolean greaterThanMedalCountMedalTotal(MedalCount mc1, MedalCount mc2)
{
    if (mc1.medalTotal > mc2.medalTotal)
        return true;
    else
        return false;
}

// %%
System.out.println(greaterThanMedalCountMedalTotal(country1, country2));
System.out.println(greaterThanMedalCountMedalTotal(country2, country1));
System.out.println(greaterThanMedalCountMedalTotal(country1, country1));

// %% [markdown]
// [Return to Exercise](#Exercise11)

// %% [markdown]
// ### Solution to Exercise 12<a id="Solution12"></a>

// %%
// Check if the first country is higher in the medal table than the second
// Based on who has most golds, then most silvers, then most bronzes.
//
public boolean greaterThanMedals(Medals country1, Medals country2)
{
    if (country1.gold > country2.gold)
        return true;
    else if (country1.gold < country2.gold)
        return false;
    else if (country1.silver > country2.silver) // golds must be equal by this point
        return true;
    else if (country1.silver < country2.silver)
        return false;
    else if (country1.bronze > country2.bronze) // golds and silvermust be equal by this point
        return true;
    else
        return false;
}

// %%
Medals country1 = new Medals();
country1.country = "China";
country1.gold = 38;
country1.silver = 32;
country1.bronze = 17;

Medals country2 = new Medals();
country2.country = "USA";
country2.gold = 39;
country2.silver = 41;
country2.bronze = 33;

Medals country3 = new Medals();
country3.country = "Mars";
country3.gold = 2;
country3.silver = 60;
country3.bronze = 12;

Medals country4 = new Medals();
country4.country = "Venus";
country4.gold = 2;
country4.silver = 15;
country4.bronze = 277;

System.out.println(greaterThanMedals(country1, country2));
System.out.println(greaterThanMedals(country1, country3));
System.out.println(greaterThanMedals(country1, country4));
System.out.println(greaterThanMedals(country1, country1));

// %% [markdown]
// [Return to Exercise](#Exercise12)

// %% [markdown]
// ### Solution to Exercise 13: Summary
//
// Sorting is to put things in to order and to do that you need an operator that for the values you want to sort tells you which comes before which. It should be able to do this for any pair. Given two values it returns true if they are in the right order and false if they are in the wrong order. < and > (for integers and characters) or a method based on compareTo (for strings) can be used to do this. When we define our own types (eg records) we must defined the order of the records our self by defining a method that does this ordering.
//
// Once we have a method for ordering values of a given type we can then use it in a method that implements a sort algorithm to sort arrays of such values (eg sort arrays of Strings or arrays of medal counts i.e. medal tables). Essentially the same method can then be used to sort anything, just by swapping in an appropriate comparison method.

// %% [markdown]
// [Return to Exercise](#Exercise13)
