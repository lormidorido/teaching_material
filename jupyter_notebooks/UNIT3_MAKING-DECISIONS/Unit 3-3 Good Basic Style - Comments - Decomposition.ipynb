// %% [markdown]
// # Unit 3 Part 3: Good Basic Style - Comments and Decomposition
//
// ## Paul Curzon
//
// ## Interactive Programming Exercises
//
// ### Learning Outcomes
// - Explain what is meant by good basic style in a program and why it is important
// - Write programs that are easier to read and understand because they are written with good style and in particular commented well.
// - Use commenting to help decomposition
//
// *This notebook looks at code fragments. After completing these exercises you MUST then go on to write full programs - see the programming exercises in the workbook.*
//
// *Answers to exercises are given at the end*
//
// **Always read the answers to exercises and compare them to your own. There are important things to learn from the answers.**
//
// <span style="color: red;"> It is a really good idea to add your own notes throughout this notebook to reinforce what you have learnt and highlight important points. Click on the + in the toolbar above to make a new note area, and change it from Code to Markdown in the dropdown menu above if your note is not executable code. You may also want to highlight your notes in red as here, so they stand out. You change colours using span like this: </span>
// ```
// <span style="color: red;">THE TEXT TO COLOUR RED</span>
// ```

// %% [markdown]
// ## Introduction
// Good style is about writing code in a way that makes it easier to read and so understand and so both get right originally as well as modify without introducing mistakes later.
//
// There are lots of aspects to good style but the basics are
// - write useful comments, not too many, not too few
// - indent your code and line up curly brackets
// - use blank lines to make separate blocks or methods stand out as separate
// - choose good, meaningful variable names
// - choose good meaningful method names
// - use final variables for literal values
//
// More sophisticated forms of good style that are critical to making code readable are good: decomposition (breaking a program into methods corresponding to sub-tasks), generalisation (writing general methods that can be used for several related tasks) and abstraction (hiding the detail of things so you can focus on what is important with the coding task at hand). The use of these form the foundation of what is meant by computational thinking.

// %% [markdown]
// In this notebook we focus first on good commenting of code which also leads to some simple points about decomposition. We will see how thinking about comments can help improve the decomposition of code into methods.

// %% [markdown]
// ## Start the program with a comment ##

// %% [markdown]
// *All* programs should start with a comment at the very start (outside the class and before any libraries are loaded). These whole program comments include at the very least what the program is for, the name of the author (in tests and exams you can use your Student id), the date it was written (and ideally a version number). These can be written using block comments like this that start with /* and end with */:

// %%
/*
 * A program to act as my intelligent digital assistant
 *
 * AUTHOR: Tony Stark
 * DATE: 17 January 2008
 * Version: 1
*/

// %% [markdown]
// The extra stars are just there to make the comment block stand out.
//
// An alternative is to comment the start of each line (again the stars are just used to maek it stand out).

// %%
// ****************************************************
// A program to act as my intelligent digital assistant
//
// AUTHOR: Tony Stark
// DATE: 17 January 2008
// Version: 1
// ****************************************************

// %% [markdown]
// ### Exercise 1<a id="Exercise1"></a>
//
// Paul Curzon wrote the following hello world program on the 17th Decemeber 2021. It has been modified once. Add an appropriate comment at the start of the program.

// %%
class HappyHoliday
{
    public static void main (String[] args)
    {
        System.out.println("I hope you have an enjoyable holiday");
        
        return;
    }
}

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution1)

// %% [markdown]
// Get into the habit of writing comment blocks like this at the start of every program you write. Do it first before writing the program. (In online, open book tests you can even write a template program block in advance, just filling in what it does in the exam itself).
//
// A more complex program might have a more detailed explanation of what it was for and why alng with any assmptions about when it would be used.

// %% [markdown]
// ### Exercise 2<a id="Exercise2"></a>
//
// Explain why writing a comment like this at the start of a program is a good idea.

// %% [markdown]
// **Write your explanation here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution2)

// %% [markdown]
// ## Do not over comment: the wrong kind of comment ##

// %% [markdown]
// A common novice mistake is to over-comment. In the worst case this means writing so many comments that the code itself can no longer be easily seen. Also it often involves writing the wrong kind of comments. Comments should not say what individual lines do but what a logical block of code does. Comments such as the following are useless in real programs. They are often used in teaching to indicate to a novice what a line does. However, real comments you write should be for people who can code, so should not just repeat in English what is easily understandable from just reading that line (if the reader is someone who can program). Comments should give the bigger picture so that they tell you what the code does overall, so by reading one comment you understand what a whole block of code does.
//
// **You should NOT write comments like any of the ones below in your programs, or comment each line like this.**

// %%
public static void printTemperatures () //create printTemperatures method
{
    int temperature = 0; // declares and sets temperature variable to 0
    
    System.out.println("It is cold."); // prints It is cold to the screen
    temperature = 32; // assigns 32 to temperature
    System.out.println("It is now really hot."); // prints It is now really hot.
    return; // return from method
}

// %%
printTemperatures (); // call method printTemperatures
// Out:
// It is cold.
// It is now really hot.

// %% [markdown]
// **ALL the above comments are bad comments.**
//
// If you were writing comments for code like this it would be better to comment the section of code. If you break your code into small methods then that means just commenting the method, like this:

// %%
// Set a cold temperature and print that it is cold
// before changing it to hot and printing a message about that
//
public static void printTemperatures ()
{
    int temperature = 0;
    
    System.out.println("It is cold.");
    temperature = 32;
    System.out.println("It is now really hot.");
    return;
}

// %%
printTemperatures ();
// Out:
// It is cold.
// It is now really hot.

// %% [markdown]
// Notice that no individual lines are commented here. The method as a whole is commented with a comment that gives a bigger picture of what the method does overall.

// %% [markdown]
// ### Exercise 3<a id="Exercise3"></a>
//
// Remove all poor comments from the following and then add a single good comment.

// %%
public static void printRainbow ()  // create a printRainbow method
{
    int count = 1;  // set count to 1
    System.out.println(count + " Red"); // print 1 Red
    count = count + 1; //increase count by 1
    System.out.println(count + " Orange");  // print 2 Orange
    count = count + 1; //increase count by 1
    System.out.println(count + " Yellow");   // print 3 Yellow
    count = count + 1; //increase count by 1
    System.out.println(count + " Green"); //print 4 Green
    count = count + 1; //increase count by 1
    System.out.println(count + " Blue"); // print 5 Blue
    count = count + 1; //increase count by 1
    System.out.println(count + " Indigo"); // print 6 Indigo
    count = count + 1; //increase count by 1
    System.out.println(count + " Violet"); // print 7 Violet

    return;  // end the method
}

// %%
printRainbow ();
// Out:
// 1 Red
// 2 Orange
// 3 Yellow
// 4 Green
// 5 Blue
// 6 Indigo
// 7 Violet

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution3)

// %% [markdown]
// ### Exercise 4<a id="Exercise4"></a>
//
// Explain why writing too many comments is bad, and fewer comments can be good.

// %% [markdown]
// **Write your explanation here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution4)

// %% [markdown]
// ## Comment tricky bits of code ##

// %% [markdown]
// The one situation where you might comment an individual line is if it is doing something a little tricky, so that a good programmer might not immediately see what was happening. One example like this might be when using the modulus (remainder when dividing) operator to do clock arithmetic such as in the following. The idea here is to have a test for even numbers so every second day is identified. Whilst a programmer might understand that % does clock arithmetic they may not immediately see why it is done here without a comment.

// %%
public static void tabletDays (int day)
{
    if (day % 2 == 0) // distinguish odd and even days as only take tablets every second day
    {
        System.out.println("Take a tablet today");
    }
    else
    {
        System.out.println("No tablets today");
    }
    
    return;
}

// %%
tabletDays(5);
tabletDays(8);
// Out:
// No tablets today
// Take a tablet today

// %% [markdown]
// However, in a situation like this there is often actually a better way than commenting the line. That test above is doing a well-defined (if hard to work out) task. Well-defined tasks are better split off as a method. For example, we can have a method that calculates if it is every second day or not as below.
//
// The method itself can then be commented, rather than the line, and its name makes much clearer what it is doing as in the following. By using good variable and method names, the need for commented lines can often be avoided as the name gives the information a comment would.
//
// We still need a comment to explain the tricky bit of code, but now we are back to following the original rule:
//
// **ONLY COMMENT METHODS NOT LINES**
//
// because we have made better use of methods. Below we leave writing the comments as an exercise for you to do.

// %%
public static boolean isEverySecondDay (int day)
{
    return (day % 2 == 0);
}

// %%
public static void tabletDays (int day)
{
    if (isEverySecondDay(day) )
    {
        System.out.println("Take a tablet today");
    }
    else
    {
        System.out.println("No tablets today");
    }
    
    return;
}

// %%
tabletDays(5);
tabletDays(8);
// Out:
// No tablets today
// Take a tablet today

// %% [markdown]
// ### Exercise 5<a id="Exercise5"></a>
//
// Add suitable comments to both the methods above.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution5)

// %% [markdown]
// ## Comment blocks ##

// %% [markdown]
// Rather than commenting lines it is appropriate to comment blocks of code. That is what we are doing by commenting methods as a method contains a block of code. However, blocks are also used in if statements and as we will see later loops. They could be commented as a whole too.
//
// For example, if two if statements follow each other you might comment each saying what they each do overall.

// %% [markdown]
// ### Exercise 6<a id="Exercise6"></a>
//
// Add a comment before each if statement in the following:

// %%
// Print the position in the rainbow of a given colour.
//
public static void printRainbowMessage (String colour)
{
    int positionInRainbow;
    
    if (colour.equals("Red"))
    {
        positionInRainbow = 1;
    }
    else  if (colour.equals("Orange"))
    {
        positionInRainbow = 2;
    }
    else if (colour.equals("Yellow"))
    {
        positionInRainbow = 3;
    }
     else if (colour.equals("Green"))
    {
        positionInRainbow = 4;
    }
     else if (colour.equals("Blue"))
    {
        positionInRainbow = 5;
    }
     else if (colour.equals("Indigo"))
    {
        positionInRainbow = 6;
    }
    else if (colour.equals("Violet"))
    {
        positionInRainbow = 7;
    }
    else
    {
        positionInRainbow = -1;
    }

             
    if (positionInRainbow == -1)
    {
        System.out.println("Sorry, that is not a traditional colour of the rainbow.");
    }
    else 
    {
        System.out.println(colour + " is in position " + positionInRainbow);
    }
             
    return;
}

// %%
// Test code for the above

printRainbowMessage ("Orange");
printRainbowMessage ("Indigo");
printRainbowMessage ("Pink");
// Out:
// Orange is in position 2

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution6)

// %% [markdown]
// As with the earlier example, though, there is a better way than writing comments in the middle of a method. The fact that we can write a comment for these two parts is a good indication that they do clearly defined tasks so should be separate methods. The length of the method, which is a lot to take in in one go, also implies it would be better decomposed too. A better solution is therefore not one method but splitting it into three methods as follows (one for each if statement and one to call each in turn.
//
// Again, this does not remove the need for comments but reinstates the rule that comments should be before methods not inside them.

// %%
// Find the position of the colour in the rainbow starting with Red as 1.
// Return -1 as a sentinel value to mean "not known".
//
public static int getRainbowPosition (String rainbowColour)
{
    int positionInRainbow;
    
    if (rainbowColour.equals("Red"))
    {
        positionInRainbow = 1;
    }
    else  if (rainbowColour.equals("Orange"))
    {
        positionInRainbow = 2;
    }
    else if (rainbowColour.equals("Yellow"))
    {
        positionInRainbow = 3;
    }
     else if (rainbowColour.equals("Green"))
    {
        positionInRainbow = 4;
    }
     else if (rainbowColour.equals("Blue"))
    {
        positionInRainbow = 5;
    }
     else if (rainbowColour.equals("Indigo"))
    {
        positionInRainbow = 6;
    }
    else if (rainbowColour.equals("Violet"))
    {
        positionInRainbow = 7;
    }
    else
    {
        positionInRainbow = -1;
    }
    
    return positionInRainbow;
}

// %%
// Test the above method
System.out.println(getRainbowPosition ("Yellow"));
System.out.println(getRainbowPosition ("Violet"));
System.out.println(getRainbowPosition ("Black"));
// Out:
// 3
// 7
// -1

// %% [markdown]
// As we are using two methods, the first has to pass information to the second. It does this by returning the **value** of the position it has calculated back to whatever calls it. Notice here the variable *positionInRainbow* is local to this method. It does not exist in the other methods. The methods below store the same value in their own different variables, named different things. They could be named the same thing but they would still be different variables, different storage spaces, as all methods have their own storage space not shared with others.
//
// Notice we can now test this method separately (as above, printing the values the method returns) to check that it returns correct values, before moving on to the next method. To be sure we should run tests for every branch in the code to be sure (not just the three above). As an extra exercise add more tests to make sure it always works.

// %%
// Given a colour and its position in the rainbow (starting with Red as 1)
// Print a message about the colour and the position it is in
// -1 is a sentinel value to mean "not known".
//
public static void printRainbowMessageGivenPosition (String colour, int position)
{            
    if (position == -1)
    {
        System.out.println("Sorry, that is not a traditional colour of the rainbow.");
    }
    else 
    {
        System.out.println(colour + " is in position " + position);
    }
             
    return;
}

// %% [markdown]
// To print the message we need to be given both the colour and position to use in the message to print. We create local variables as arguments and these values must be passed to the method when it is called as in our tests below. As this method prints things rather than returns a value, we do not need print statements in the tests here.

// %%
// Test this method
printRainbowMessageGivenPosition ("Red", 1);
printRainbowMessageGivenPosition ("Green", 4);
printRainbowMessageGivenPosition ("Mauve", -1);
// Out:
// Red is in position 1
// Green is in position 4
// Sorry, that is not a traditional colour of the rainbow.

// %% [markdown]
// Here we were just testing the method so had to pick correct pairs of numbers and colours ourself. The next method now puts the above two parts together, by calling the first part to find out the correct number and then passing that information to the second (along with the colour) so it can print the right message.

// %%
// Print a message about the position a colour appears in the rainbow.
// -1 is a sentinel value to mean "not known".
//
public static void printRainbowMessage (String rainbowColour)
{
    int rainbowPosition;
    
    rainbowPosition = getRainbowPosition (rainbowColour);
    printRainbowMessageGivenPosition (rainbowColour, rainbowPosition);
             
    return;
}

// %% [markdown]
// This is the method that replaces the original one. It does exactly the same thing but in two steps (each a method call) - calling the method to work out what the position is, and store that locally. That allows it to pass the value stored there to the second method. It prints the message.
//
// We can now understand each part (each method) separately and the naming of the methods help us understand how this last method achieves it's effect by first getting the position and then printing a message about it.
//
// Thinking about better commenting has led us to a way to write better code, by decomposing it into parts that we comment separately.

// %%
// Test the above method
printRainbowMessage ("Indigo");
printRainbowMessage ("White");
// Out:
// Indigo is in position 6

// %% [markdown]
// ### Exercise 7<a id="Exercise7"></a>
//
// Improve the following method by splitting it into three methods and commenting each. It is intended to print the final positions of the finalists on Strictly 2021.
//
// SPOILER ALERT!!!

// %%
public static void printStrictlyFinalists (String finalist)
{
    int strictlyPosition;
    
    if (finalist.equals("Rose"))
    {
        strictlyPosition = 1;
    }
    else  if (finalist.equals("John"))
    {
        strictlyPosition = 2;
    }
    else if (finalist.equals("AJ"))
    {
        strictlyPosition = 3;
    }
    else
    {
        strictlyPosition = -1;
    }

             
    if (strictlyPosition == -1)
    {
        System.out.println("That person was not a finalist.");
    }
    else 
    {
        System.out.println(finalist + " finished as number " + strictlyPosition);
    }
             
    return;
}

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution7)

// %%
// Test above method
printStrictlyFinalists ("AJ");
printStrictlyFinalists ("Rose");
printStrictlyFinalists ("John");
printStrictlyFinalists ("Rhys");
// Out:
// AJ finished as number 3
// Rose finished as number 1
// John finished as number 2
// That person was not a finalist.

// %% [markdown]
// ### Exercise 8<a id="Exercise8"></a>
//
// Explain how  to write good comments.

// %% [markdown]
// **Write your explanation here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution8)

// %% [markdown]
// *Once you have done the above exercises (and understand how the concepts work) move on to doing the actual programming exercises from the handbook, writing full programs. You must be able to write full programs, not just fragments.*

// %% [markdown]
// ## Solutions
//
// ### Solution to Exercise 1<a id="Solution1"></a>

// %%
/*
 * Print a friendly holiday message
 *
 * AUTHOR: Paul Curzon
 * DATE: 17 Dec 2021
 * Version: 2
*/

class HappyHoliday
{
    public static void main(String[] args)
    {
        System.out.println("I hope you have an enjoyable holiday");
        
        return;
    }
}

// %% [markdown]
// [Return to Exercise](#Exercise1)

// %% [markdown]
// ### Solution to Exercise 2<a id="Solution2"></a>
//
// A comment at the start makes sure everyone knows what the purpose of this program is and so does not get confused and think it does something it is not intended for (as well as knowing what it should be used for). Someone (yourself or someone else) who needs to modify it starts off immediately knowing the big picture.
//
// If it has an author and that makes it clear who has responsibility and accountability for the original and means others who have to understand it later know who to talk to if they have problems. It may also give them an idea of how good the code is (eg perhaps it is written by a genius hacker now known to write really obscure code no one can follow (so dangerous), or a novice so in either case is likely to need improvement, in general).
//
// The date and version number help people keep track of things like whether this copy is the most recent version. You do not want to start editing a copy that you later find out was much improved later with lots of bugs removed. Version histories should also be kept elsewhere to help with this.
//
// When others modify it they would also add more comments of their own to this initial comment block - giving a modification history as part of the comment block, showing who made modifications, what was changed and why.
//
// For example, with this comment at the start of a program:

// %%
/*
 * Automatically generate all marks from students separate scripts.
 * Assumes the marks are in a pdf form in a single box called Mark
 *
 * AUTHOR: Paul Curzon
 * DATE: 18 Dec 2021
 * Version: 1
*/

// %% [markdown]
// We not only know what the program is for but also expectations about the way it must be used (stating assumptions a program makes is very important at the start). We also know who is responsible for it (so who to contact for explanation if needed), and exactly which version we are looking at to help avoid mistakes.

// %% [markdown]
// [Return to Exercise](#Exercise2)

// %% [markdown]
// ### Solution to Exercise 3<a id="Solution3"></a>

// %%
// Print the colours of the rainbow in numbered order starting from 1
//
public static void printRainbow()
{
    int count = 1;
    System.out.println(count + " Red");
    count = count + 1;
    System.out.println(count + " Orange");
    count = count + 1;
    System.out.println(count + " Yellow");
    count = count + 1;
    System.out.println(count + " Green");
    count = count + 1;
    System.out.println(count + " Blue");
    count = count + 1;
    System.out.println(count + " Indigo");
    count = count + 1;
    System.out.println(count + " Violet");

    return;
}

printRainbow();
// Out:
// 1 Red
// 2 Orange
// 3 Yellow
// 4 Green
// 5 Blue
// 6 Indigo
// 7 Violet

// %% [markdown]
// [Return to Exercise](#Exercise3)

// %% [markdown]
// ### Solution to Exercise 4<a id="Solution4"></a>
//
// Writing too many comments is bad because it hides the actual code, so making it less readable not more. Comments are for people who can program to read so do not need to say what individual lines do, as a novice might need, but instead need to give the big picture of what the code as a whole does. If too many comments are written then that big picture is lost amongst all the detailed comments that a programmer wouldn't need anyway as they would understand the same thing by just reading the line of code.

// %% [markdown]
// [Return to Exercise](#Exercise4)

// %% [markdown]
// ### Solution to Exercise 5<a id="Solution5"></a>

// %%
// Determine if it is an even day (ie return true every second day)
//
public static boolean isEverySecondDay(int day)
{
    return (day % 2 == 0);
}

// %%
// Tell people whether they need to take a tablet when they must take one, miss a day, take one, miss a day,..
//
public static void tabletDays(int day)
{
    if (isEverySecondDay(day) )
    {
        System.out.println("Take a tablet today");
    }
    else
    {
        System.out.println("No tablets today");
    }
    
    return;
}

// %% [markdown]
// [Return to Exercise](#Exercise5)

// %% [markdown]
// ### Solution to Exercise 6<a id="Solution6"></a>

// %%
// Print the position in the rainbow of a given colour.
//
public static void printrainbowColourPositions(String colour)
{
    int positionInRainbow;
    
    // First find the position of the colour in the rainbow starting with Red as 1
    // Uses -1 as a sentinel value to mean "not known".
    //
    if (colour.equals("Red"))
    {
        positionInRainbow = 1;
    }
    else  if (colour.equals("Orange"))
    {
        positionInRainbow = 2;
    }
    else if (colour.equals("Yellow"))
    {
        positionInRainbow = 3;
    }
     else if (colour.equals("Green"))
    {
        positionInRainbow = 3;
    }
     else if (colour.equals("Blue"))
    {
        positionInRainbow = 3;
    }
     else if (colour.equals("Indigo"))
    {
        positionInRainbow = 3;
    }
    else if (colour.equals("Violet"))
    {
        positionInRainbow = 3;
    }
    else
    {
        positionInRainbow = -1;
    }

    // Then Print a message about that colour, giving an error message if it is unknown
    //             
    if (positionInRainbow == -1)
    {
        System.out.println("Sorry, that is not a traditional colour of the rainbow.");
    }
    else 
    {
        System.out.println(colour + " is in position " + positionInRainbow);
    }
             
    return;
}

// %% [markdown]
// [Return to Exercise](#Exercise6)

// %% [markdown]
// ### Solution to Exercise 7<a id="Solution7"></a>

// %%
// Return the integer final position of a given person in the final of Strictly COme Dancing 2021
// Return -1 if the given person was not a finalist
//
public static int getStrictlyFinalistPosition (String finalist)
{
    int strictlyPosition;
    
    if (finalist.equals("Rose"))
    {
        strictlyPosition = 1;
    }
    else  if (finalist.equals("John"))
    {
        strictlyPosition = 2;
    }
    else if (finalist.equals("AJ"))
    {
        strictlyPosition = 3;
    }
    else
    {
        strictlyPosition = -1;
    }
   
    return strictlyPosition;
}

// %%
// Given the name of a finalist in Strictly 2021 and their position, 
// print a message stating where they finished
// If given -1 as the position then they were not a finalist
//
public static void printStrictlyFinalistsAndPositions (String strictlyFinalist, int strictlyPosition)
{
    if (strictlyPosition != -1)
    {
        System.out.println(strictlyFinalist + " finished as number " + strictlyPosition);
    }
    else 
    {
        System.out.println("That person was not a finalist.");
    }
    
    return;
}

// %%
// Given the name of a finalist in Strictly come dancing 2021, print a message giving their final position
//
public static void printStrictlyFinalists (String finalist)
{
    int strictlyPosition;
    
    strictlyPosition = getStrictlyFinalistPosition (finalist);
    printStrictlyFinalistsAndPositions (finalist, strictlyPosition);
         
    return;
}

// %%
printStrictlyFinalists ("AJ");
printStrictlyFinalists ("Rose");
printStrictlyFinalists ("John");
printStrictlyFinalists ("Rhys");
// Out:
// AJ finished as number 3
// Rose finished as number 1
// John finished as number 2
// That person was not a finalist.

// %% [markdown]
// [Return to Exercise](#Exercise7)

// %% [markdown]
// ### Solution to Exercise 8<a id="Solution8"></a>

// %% [markdown]
// All programs must be commented. However, writing good comments involves not writing too many or too few. If you write too few then someone reading the program will find it harder to read than need be as methods may be less clear than required. If you write too many then the code is lost in the comments. A good rule is to aim to write a comment before each method saying what it does. This works as long as the program as a whole has been decomposed well so that each sub-task is implemented as its own method. This means methods are short and do a well-defined task.
//
// Comments should not be line by line and should certainly not just say what individual lines do. They should instead aim to give the big picture. An exception to this is where some coding trick has been used to achieve some result that would be hard for even a proficient reader to fathom. Then the specific trick should be explained. However, this may be an indication that a method should be used to bind up that trick into a method with a name that indicates what it does and so is for. Then it would be the method that would be

// %% [markdown]
// [Return to Exercise](#Exercise8)
