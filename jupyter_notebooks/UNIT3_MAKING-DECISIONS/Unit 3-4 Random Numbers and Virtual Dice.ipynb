// %% [markdown]
// # Unit 3 Part 4: Random Numbers and Virtual Dice
//
// ## Paul Curzon
//
// ## Interactive Programming Exercises
//
// ### Learning Outcomes
// - Explain how random numbers can be generated by a program
// - Write programs that use random numbers so have different behaviour each time they run
//
// You may want to leave this notebook until you need random numbers in one of your programs.
//
// *This notebook looks at code fragments. After completing these exercises you MUST then go on to write full programs - see the programming exercises in the workbook.*
//
// *Answers to exercises are given at the end*
//
// **Always read the answers to exercises and compare them to your own. There are important things to learn from the answers.**
//
// <span style="color: red;"> It is a really good idea to add your own notes throughout this notebook to reinforce what you have learnt and highlight important points. Click on the + in the toolbar above to make a new note area, and change it from Code to Markdown in the dropdown menu above if your note is not executable code. You may also want to highlight your notes in red as here, so they stand out. You change colours using span like this: </span>
// ```
// <span style="color: red;">THE TEXT TO COLOUR RED</span>
// ```

// %% [markdown]
// ## Introduction
// Many programs need randomness. Games are the obvious example. If you played a chess program and it always made the same moves so was totally predictable it would ultimately be easy to win.
//
// However, programs do exactly what their instructions tell them to, so this implies that with the same inputs they will do exactly the same thing.
//
// This apparent paradox is broken using random number generators. Essentially programming languages provide a method that gives back different numbers each time it is called. This could for example, be based on how many nanoseconds the machine has been running.

// %% [markdown]
// ## Streams of random numbers

// %% [markdown]
// The java.util.Random library provides one way to include random numbers in a program that works in a simple way to the way input from the keyboard is done.

// %% [markdown]
// ### Exercise 1<a id="Exercise1"></a>
//
// Study the following method (remembering it works a bit like keyboard input) and see if you can predict what it does and how. If you have an idea, write your prediction in the box below.

// %%
public static void generateRandomNumber()
{
    Random stream_of_random_numbers = new Random();
    
    int random_number = stream_of_random_numbers.nextInt(3);
    
    System.out.println(random_number);
    
    return;
}

// %% [markdown]
// **Write your prediction here**

// %% [markdown]
// Now compile the method above and run it by calling the method by running the block below. Run the method lots of times looking at what is printed each time. Decide if your prediction was right or not. If your understanding has changed write a new version of what it does below. If you couldn't make a prediction before write what you think is happening now.

// %%
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
generateRandomNumber();
// Out:
// 1
// 2
// 2
// 1
// 2
// 2
// 0
// 0
// 1
// 2

// %% [markdown]
// **Write your new understanding here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution1)

// %% [markdown]
// ### Exercise 2<a id="Exercise2"></a>
//
// The above method prints a random number taken from the possibilities 0, 1 or 2. It prints a different random number from these each time it is called.
//
// **Modify** the method below to create a new method that generates random numbers between 0 and 5 inclusive. Make sure you call the variables something descriptive of what they do.

// %%
// This prints a random number between 0 and 5 inclusive
// Modify this method to do this new task
//
public static void generateRandomNumber0to5()
{
    Random stream_of_random_numbers = new Random();
    
    int random_number = stream_of_random_numbers.nextInt(3);
    
    System.out.println(random_number);
    
    return;
}

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution2)

// %% [markdown]
// ### Loading the library
//
// NOTE: In a full program you would need to load in the java.util.Random to be able to use random numbers. This is done by importing it using
//
// ```
// import java.util.Random;
// ```
//
// This library is already loaded for you in JHUB programs.

// %% [markdown]
// ### Exercise 3<a id="Exercise3"></a>
//
// If you want to create a virtual 6-sided dice then you probably don't want it to contain the numbers 0,1,2,3,4,5. You probably want 1,2,3,4,5,6!
//
// Write a method that does that acting exactly like a normal 6-sided dice. HINT: what addition would change the numbers 0,1,2,3,4,5 into 1,2,3,4,5,6? Test it to check it works.

// %%
// Write your method here

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution3)

// %% [markdown]
// ### Exercise 4<a id="Exercise4"></a>
//
// Rather than just print a random number, it is likely what is really wanted is a method that returns a random number in some given range that can then be used.
//
// **Write** a method called eg dice that **returns** a random number between 1 and 6 each time it is called. **Write** also a test method that calls and prints what it returns.

// %%
// Write your method here

// %%
// Write your test method here

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution4)

// %% [markdown]
// ### Exercise 5<a id="Exercise5"></a>
// So to get numbers from 1 upwards you just have to add 1 to the basic random number returned. Not all dice are six sided. Dungeons and dragons style games for example use 10- and 20-sided dice.
//
// **Write** a method that acts like a 10-sided dice, returning a number from 0 to 10. **Write** a test method for it.

// %%
// Write your method here

// %%
// Write your test method here

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution5)

// %% [markdown]
// ### Exercise 6<a id="Exercise6"></a>
//
// Dice, and other devices for generated randomness, don't always have numbers on them. That is where IF statements can come in. Work out what the following does. Change its name to something better and add a suitable comment at the start.

// %%
//
public static String generateRandomString()
{
    String toss;
    Random stream_of_random_numbers = new Random();
    
    int random0to1 = stream_of_random_numbers.nextInt(2);
    
    if (random0to1 == 0)
        toss = "HEADS";
    else
        toss = "TAILS"; 
        
    return toss;
}

// %%
// Test the above method
System.out.println(generateRandomString());
System.out.println(generateRandomString());
System.out.println(generateRandomString());
System.out.println(generateRandomString());
System.out.println(generateRandomString());
// Out:
// TAILS
// HEADS
// HEADS
// HEADS
// TAILS

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution6)

// %% [markdown]
// ### Exercise 7<a id="Exercise7"></a>
//
// Write and test a method for a cricket game that returns one of three values "FOUR", "SIX" or "OUT".

// %%
// Write your method here

// %%
// Write your test method here

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution7)

// %% [markdown]
// Later you will see that there is an even more elegant way to convert numbers into Strings or other values using, for example, an array  as a lookup table (covered in a later unit).

// %% [markdown]
// ### Exercise 8<a id="Exercise8"></a>
//
// Summarise what you know about generating random numbers.

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution8)

// %% [markdown]
// ## Solutions
//
// ### Solution to Exercise 1<a id="Solution1"></a>

// %% [markdown]
// The method as a whole prints a single random number between 0 and 2 inclusive. Each time the method is called it gives a new random number in that range.
//
// The line:
// ```
// Random stream_of_random_numbers = new Random();
// ```
// creates a new stream of random numbers stored in a variable called ```stream_of_random_numbers```
// It is just a variable so you could have called it anything.
//
// You can imagine it as an infinite list of numbers. Those numbers can be 'plucked' off the list one at a time when needed.
//
// The method nextInt plucks the next number off the list so
// ```
// stream_of_random_numbers.nextInt(3);
// ```
// returns a single random number (removing it from the front of the list so that next time it is called another random number is released).
//
// Why is the argument 3 needed? The numbers in the list are actually real numbers between 0 and 2. This means they have to be converted to the range needed. If you want a normal 6-sided dice you need numbers between 1 and 6 for example. The number 3 gives the range. It means the numbers returned are integers between 0 and 3. It is not as you might have thought giving the upper number but the number of possible different numbers that will be generated. By putting 3 there you are saying you want 1 of 3 different numbers to be generated starting from 0 (so from {0,1,2})
//
// You may have incorrectly guessed that it would return numbers 1 or 2. In fact it always produces a number from 0 up to one less than the number given.
//
// In the method, the number returned is stored in the integer variable we called ```random_number```. Again it is just a variable and we could have called it anything. Always call the variable something descriptive.
//
// ```
// int random_number = stream_of_random_numbers.nextInt(3);
// ```

// %% [markdown]
// [Return to Exercise](#Exercise1)

// %% [markdown]
// ### Solution to Exercise 2<a id="Solution2"></a>

// %%
// This prints a random number between 0 and 5 inclusive

public static void generateRandomNumber0to5()
{
    Random stream_of_random_numbers = new Random();
    
    int random_number0to5 = stream_of_random_numbers.nextInt(6);
    
    System.out.println(random_number0to5);
    
    return;
}

// %%
// Test the above method. It should return random numbers between 0 and 5 inclusive
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
generateRandomNumber0to5();
// Out:
// 2
// 1
// 5
// 0
// 4
// 3
// 4
// 2
// 0
// 5

// %% [markdown]
// We not only know what the program is for but also expectations about the way it must be used (stating assumptions a program makes is very important at the start). We also know who is responsible for it (so who to contact for explanation if needed), and exactly which version we are looking at to help avoid mistakes.

// %% [markdown]
// [Return to Exercise](#Exercise2)

// %% [markdown]
// ### Solution to Exercise 3<a id="Solution3"></a>

// %% [markdown]
// You just need to add 1 to the random number returned. That turns any random number 0 into 1, 1 into 2 and so on up to 5 into 6, giving the right range of numbers.

// %%
// This prints a random number between 1 and 6 inclusive

public static void generateRandomNumber1to6()
{
    Random stream_of_random_numbers = new Random();
    
    int random_number0to5 = stream_of_random_numbers.nextInt(6);
    int random_number1to6 = random_number0to5 + 1;
         
    System.out.println(random_number1to6);
    
    return;
}

// %%
// Test the above method. It should return random numbers between 0 and 5 inclusive
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
generateRandomNumber1to6();
// Out:
// 5
// 4
// 3
// 4
// 4
// 6
// 2
// 6
// 3

// %% [markdown]
// [Return to Exercise](#Exercise3)

// %% [markdown]
// ### Solution to Exercise 4<a id="Solution4"></a>
//
// The method needs to just return the result rather than print it. Remember the return type needs to be changed from void to int in the header line.

// %%
// Return a random number between 1 and 6 inclusive, 
// so acting like a normal dice.

public static int dice()
{
    Random stream_of_random_numbers = new Random();
    
    int random1to6 = 1 + stream_of_random_numbers.nextInt(6);
     
    return random1to6;
}

// %%
// A method to use and so test the above dice method

public static void testDice()
{    
    int dice_throw1 = dice();
    int dice_throw2 = dice();
    int dice_throw3 = dice();
    int dice_throw4 = dice();
    
    System.out.println(dice_throw1);
    System.out.println(dice_throw2);
    System.out.println(dice_throw3);
    System.out.println(dice_throw4);
     
    return;
}

// %%
// Call the test method

testDice();
// Out:
// 1
// 6
// 2
// 6

// %% [markdown]
// Notice how once we have packaged exactly what we want the dice to do into the dice method we no longer need to worry about how it works (so the Random stream or setting the range of numbers any more. We just call our method. It returns a result which we store in a variable to do whatever is needed with it!

// %% [markdown]
// [Return to Exercise](#Exercise4)

// %% [markdown]
// ### Solution to Exercise 5<a id="Solution5"></a>

// %%
// Return a random number between 1 and 10 inclusive, 
// so acting like a normal dice.

public static int dice10()
{
    Random stream_of_random_numbers = new Random();
    
    int random1to10 = 1 + stream_of_random_numbers.nextInt(10);
     
    return random1to10;
}

// %%
// A method to use and so test the above dice method

public static void testDice10()
{    
    int dice_throw1 = dice10();
    int dice_throw2 = dice10();
    int dice_throw3 = dice10();
    int dice_throw4 = dice10();
    
    System.out.println(dice_throw1);
    System.out.println(dice_throw2);
    System.out.println(dice_throw3);
    System.out.println(dice_throw4);
     
    return;
}

// %%
testDice10();
// Out:
// 1
// 9
// 6
// 7

// %% [markdown]
// [Return to Exercise](#Exercise5)

// %% [markdown]
// ### Solution to Exercise 6<a id="Solution6"></a>

// %% [markdown]
// The code does the equivalent of a coin toss returning one of two possible strings at random - either Heads or TAILS.

// %%
// Toss a coin virtually retirning either the String HEADS or TAILS
//
public static String coinToss()
{
    String toss;
    Random stream_of_random_numbers = new Random();
    
    int random0to1 = stream_of_random_numbers.nextInt(2);
    
    if (random0to1 == 0)
        toss = "HEADS";
    else
        toss = "TAILS"; 
        
    return toss;
}

// %%
System.out.println(coinToss());
System.out.println(coinToss());
System.out.println(coinToss());
System.out.println(coinToss());
System.out.println(coinToss());
System.out.println(coinToss());
System.out.println(coinToss());
// Out:
// TAILS
// HEADS
// HEADS
// TAILS
// TAILS
// TAILS
// TAILS

// %% [markdown]
// [Return to Exercise](#Exercise6)

// %% [markdown]
// ### Solution to Exercise 7<a id="Solution7"></a>

// %%
// Decide at random what a batsman hits in a cricket game - FOUR, SIX or OUT
//
public static String cricketHit()
{
    String hit;
    Random stream_of_random_numbers = new Random();
    
    int random0to2 = stream_of_random_numbers.nextInt(3);
    
    if (random0to2 == 0)
        hit = "FOUR";
    else if (random0to2 == 1)
        hit = "SIX"; 
    else
        hit = "OUT"; 
        
    return hit;
}

// %%
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
System.out.println(cricketHit());
// Out:
// FOUR
// OUT
// SIX
// FOUR
// FOUR
// OUT
// OUT
// FOUR
// SIX
// SIX

// %% [markdown]
// [Return to Exercise](#Exercise7)

// %% [markdown]
// ### Solution to Exercise 8<a id="Solution8"></a>

// %% [markdown]
// - Random number generators can be made available to a program by loading in the library java.util.Random.
// - First you must create a stream (essentially an infinite list) of random numbers
//     - they actually are real numbers between 0 and 1
//     - this is done using eg
//     - ```Random r = new Random();```
//     - This creates a new variable called r that holds a stream of random numbers
//     - It is very much like creating an input stream for doing keyboard input
// - Once you have a stream you can pull numbers off it one at a time using the method nextInt(...)
//     - It takes an integer argument which gives the number of possibilities for the random number returned.
//     - So if you give it the argument 4 as in nextInt(4) then it will return 1 of 4 values from 0, 1, 2, 3, 4
//     - to call it you need to link it to the particular stream of random numbers by putting the stream variable name and a . before it
//     - eg ```r.nextInt(4)```
//     - This returns an integer so it can be used or stored as any other integer. Most likely it it stored in a variable for later use.
//     - The integers returned can be converted into other values eg String text just using a conversion method with a big if statement.

// %% [markdown]
// [Return to Exercise](#Exercise8)
