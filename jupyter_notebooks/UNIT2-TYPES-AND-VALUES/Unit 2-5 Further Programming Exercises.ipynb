// %% [markdown]
// # Unit 2 Part 5: Further Programming Exercises
// ## By Paul Curzon
//
// ## Interactive Programming Exercises
//
// This notebook aims to reinforce the things learnt from doing the previous interactive notebooks in this unit. It is a series of extra programs to write as extra practice.
//
// ## Learning Outcomes
// - Write programs that use types, expressions and values
//
// *Solutions to the exercises are given at the end of the notebook. A link to each solution is included after each question.*
//
// **Always read the answers to exercises and compare them to your own. There are important things to learn from the answers.**
//
// <span style="color: red;"> It is a really good idea to add your own notes throughout this notebook to reinforce what you have learnt and highlight important points. Click on the + in the toolbar above to make a new note area, and change it from Code to Markdown in the dropdown menu above if your note is not executable code. You may also want to highlight your notes in red as here, so they stand out. You change colours using span like this: </span>
// ```
// <span style="color: red;">THE TEXT TO COLOUR RED</span>
// ```

// %% [markdown]
// ### Exercise 1 <a id="Exercise1"></a> Number Input
//
// Write a method that reads in a whole number n, and prints it out again. Modify your code so that it prints out n+1 (i.e., one more than the number typed in).
//
// Write a test plan for it - indicating a series of values to test it with and the correct answers.

// %%
// Write the method here

// %%
// Write the test plan here including calls to do the tests

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution1)

// %% [markdown]
// ### Exercise 2 <a id="Exercise2"></a>  Fahrenheit to Celsius
//
// Write a method that reads a temperature in degrees Fahrenheit and prints out the corresponding temperature in degrees Celsius (C = (F - 32) * 5 / 9).
// Make the method 'user friendly' (this applies to all subsequent programs you write - ever!). The messages to the user should be clear and easy to understand what is expected of them.

// %%
// Write the method here

// %%
// Write the test plan here including calls to do the tests

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution2)

// %% [markdown]
// ### Exercise 3<a id="Exercise3"></a> Celsius to Fahrenheit
//
// Write a program that reads a temperature in degrees Celsius and prints out the corresponding temperature in degrees Fahrenheit  (F = (C * 9 / 5) + 32).

// %%
// Write the method here

// %%
// Write the test plan here including calls to do the tests

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution3)

// %% [markdown]
// You may have noticed that the two programs do not give consistent answers converting back and forth. This is because of rounding errors due to just using integers instead of more accurate floating point (ie decimal numbers).
//
// You may want to create new versions that use values of type double throughout instead of int (with constants like 32.0 instead of just 32) and see the difference in answers.

// %% [markdown]
// ### Exercise 4 <a id="Exercise4"></a> Year Born
// Read and then run the program below and make sure you understand how it works then ...
//
// Modify the year born method below so that it asks the user for the current year first (so won't get the answer wrong in future). Do so by writing a new method that is called.
//
// Remember to always test methods individually as you write them.

// %%
/* ***************************************************
    A program that given a current age (assumed in 2022)
    and their age works out their possible years of birth.        
    
    AUTHOR Paul Curzon
    DATE 19 September 2022
*/


/* ***************************************************
    This method gets a single integer age from the user 
    and returns it
*/
public static int inputAge()
{
    Scanner scanner = new Scanner(System.in);
    int age;

    System.out.println("Tell me your age ");
    age = Integer.parseInt(scanner.nextLine());
   
    return age;
} // END inputAge

    
/* ***************************************************
       This method asks the user their age and works out their
       year of birth. It only works if current year is correct
       or the person gives their age in that year.
*/
public static void born()
{
    final int CURRENTYEAR = 2022;
    int age;            // an integer version of textinput
    int year;           // the calculated year of birth
    String answertext;  // construct the text to give the answer back 
       
    // Get an age (a string) from the user then
    // convert (known as parsing) it into a number version
    //
    age = inputAge();

    // Now do the calculation
    //
    year = CURRENTYEAR - age; 
    answertext = "You must have been born in " + year + " or " + (year - 1); 

    // Finally give the user the answer
    //   
    System.out.println(answertext);
       
    return;
} // END born

// %%
born();
// Out:
// Tell me your age
//  20
// You must have been born in 2002 or 2001

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution4)

// %% [markdown]
// ### Exercise 5<a id="Exercise5"></a> Area of a rectangle
//
// Write a program that reads the length and width of a rectangle in cm and computes its area.

// %%
// Test your program here

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution5)

// %% [markdown]
// ### Exercise 6 <a id="Exercise6"></a> Rectangle Record
//
// Write a program that creates a new record type Rectangle. Records of type Rectangle should hold two values: an integer length and an integer width. The program should ask the user for the length and width, store them in a variable of type Rectangle and then print the area of the rectangle, obtaining the values from the record.
//
// Modify your above program to do this.

// %%
// Test your program here

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution6)

// %% [markdown]
// ### Exercise 7: Company Profit<a id="Exercise7"></a>

// %% [markdown]
// Write a program that given an amount of company profit, divides it equally between 5 employees of a firm as a bonus. Use integers and integer arithmetic throughout.
//
// Does your program give an accurate answer?

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution7)

// %% [markdown]
// ### Exercise 8: Accurate Company Profit<a id="Exercise8"></a>
//
// Modify your above program to give an accurate answer using double values and double arithmetic.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution](#Solution8)

// %% [markdown]
// ## Solutions
//
// ### Solution to Exercise 1<a id="Solution1"></a>

// %%
/* ***************************************************
   This method prints one more than the number input

    AUTHOR Paul Curzon
    DATE 19 September 2022
*/
    
public static void printOneMore()
{
    Scanner scanner = new Scanner(System.in);
    
    int number_in;      
    int number_out;      

    //  Get the original number
       
    System.out.println("Please give me the number to increment.");
    number_in = Integer.parseInt(scanner.nextLine());
  
    // Now calculate the new value
    //
    number_out = number_in + 1;
    
    // Finally print the answer
    //   
    System.out.println(number_out);
    
    return;  
} // END printOneMore

// %% [markdown]
// ##### // Test above method
// // 0 -> 1
// // 56 -> 57
// // 22 -> 23
// // -10 -> -9
// printOneMore();
// printOneMore();
// printOneMore();
// printOneMore();

// %% [markdown]
// Below is a full Java program version of the above method.
//
// Note a full program to use out of an interactive notebook
// needs to be wrapped in a class with {...} round the methods.
//    The name after the word class is the name of the program
//    used to run it.
//
// It also needs a method called main to call the method that does the work. All full java
// programs start by calling main as the first thing when run.
//
// Any special libraries also need to be loaded.
//
// Check full programs compile in JHUB but run them from the desktop.

// %%
/* ***************************************************
   This full program prints one more than the number input

    AUTHOR Paul Curzon
    DATE 19 September 2022
*/

// Load libraries
import java.util.Scanner;

class PrintOneMore
{

    public static void main(String[] param)
    {
        printOneMore();
        
        return;
    }

    public static void printOneMore()
    {
        Scanner scanner = new Scanner(System.in);
        
        int number_in;      
        int number_out;      
        
        //  Get the original number
        
        System.out.println("Please give me the number to increment.");
        number_in = Integer.parseInt(scanner.nextLine());
        
        // Now calculate the new value
        //
        number_out = number_in + 1;
        
        // Finally print the answer
        //   
        System.out.println(number_out);
        
        return;  
    } // END printOneMore
    
} // END class PrintOneMore

// %% [markdown]
// [Return to Exercise](#Exercise1)

// %% [markdown]
// ### Solution to Exercise 2<a id="Solution2"></a>

// %%
/* ***************************************************
    This program converts temperatures in fahrenheit to
    celcius.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022

*/
public static void fahrenheitToCelcius()
{
    Scanner scanner = new Scanner(System.in);
    
    int celcius; 
    int fahrenheit;       

    //  Get the temperature in fahrenheit as an integer
       
    System.out.println("I convert temperatures from degrees fahrenheit to degrees celcius .");
    System.out.println("Please give me the temperature in degrees fahrenheit (a whole number).");
    fahrenheit = Integer.parseInt(scanner.nextLine());
  
    // Now do the calculation of the total age
    //
    celcius = ((fahrenheit - 32) * 5) / 9;
    
    // Finally give the user the answer
    //   
    System.out.println("The temperature " + fahrenheit + " degrees fahrenheit is " + 
                       celcius + " degrees celcius (rounded down to nearest whole number)");
    return;  
} // END fahrenheitToCelcius

// %%
// Test above method
// 32 -> 0
// 212 -> 100
// 256 -> 124
// -100 -> - 73
fahrenheitToCelcius();
fahrenheitToCelcius();
fahrenheitToCelcius();
fahrenheitToCelcius();
// Out:
// I convert temperatures from degrees fahrenheit to degrees celcius .
// Please give me the temperature in degrees fahrenheit (a whole number).
//  32
// The temperature 32 degrees fahrenheit is 0 degrees celcius (rounded down to nearest whole number)
// I convert temperatures from degrees fahrenheit to degrees celcius .
// Please give me the temperature in degrees fahrenheit (a whole number).
//  212
// The temperature 212 degrees fahrenheit is 100 degrees celcius (rounded down to nearest whole number)
// I convert temperatures from degrees fahrenheit to degrees celcius .
// Please give me the temperature in degrees fahrenheit (a whole number).
//  256
// The temperature 256 degrees fahrenheit is 124 degrees celcius (rounded down to nearest whole number)
// I convert temperatures from degrees fahrenheit to degrees celcius .
// Please give me the temperature in degrees fahrenheit (a whole number).
//  -100
// ...

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %%
/* ***************************************************
    This program converts temperatures in fahrenheit to
    celcius.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022

*/

// Load libraries
import java.util.Scanner;

class FahrenheitToCelcius
{

    public static void main(String[] param)
    {
        fahrenheitToCelcius();
        
        return;
    }
    
    
    public static void fahrenheitToCelcius()
    {
        Scanner scanner = new Scanner(System.in);
    
        int celcius; 
        int fahrenheit;       
        
        //  Get the temperature in fahrenheit as an integer
       
        System.out.println("I convert temperatures from degrees fahrenheit to degrees celcius .");
        System.out.println("Please give me the temperature in degrees fahrenheit (a whole number).");
        fahrenheit = Integer.parseInt(scanner.nextLine());
  
        // Now do the calculation of the total age
        //
        celcius = ((fahrenheit - 32) * 5) / 9;
    
        // Finally give the user the answer
        //   
        System.out.println("The temperature " + fahrenheit + " degrees fahrenheit is " + 
                           celcius + " degrees celcius (rounded down to nearest whole number)");
        return;  
    } // END fahrenheitToCelcius
}

// %% [markdown]
// [Return to Exercise](#Exercise2)

// %% [markdown]
// ### Solution to Exercise 3<a id="Solution3"></a>

// %%
/* ***************************************************
    This program converts temperatures in celcius to
    fahrenheit.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022

*/
public static void celciusToFahrenheit()
{
    Scanner scanner = new Scanner(System.in);
    
    int celcius; 
    int fahrenheit;       

    //  Get the temperature in fahrenheit as an integer
       
    System.out.println("I convert temperatures from degrees celcius to degrees fahrenheit .");
    System.out.println("Please give me the temperature in degrees celcius (a whole number).");
    celcius = Integer.parseInt(scanner.nextLine());
  
    // Now do the calculation of the total age
    //
    fahrenheit = ((celcius * 9) / 5) + 32;
    
    // Finally give the user the answer
    //   
    System.out.println("The temperature " + celcius + " degrees celcius is " + 
                       fahrenheit + " degrees fahrenheit (rounded down to nearest whole number)");
    return;  
} // END celciusToFahrenheit

// %%
// Test above method
// 0 -> 32
// 100 -> 212
// 124 -> 255
// -73 -> - 99

celciusToFahrenheit();
celciusToFahrenheit();
celciusToFahrenheit();
celciusToFahrenheit();
// Out:
// I convert temperatures from degrees celcius to degrees fahrenheit .
// Please give me the temperature in degrees celcius (a whole number).
//  0
// The temperature 0 degrees celcius is 32 degrees fahrenheit (rounded down to nearest whole number)
// I convert temperatures from degrees celcius to degrees fahrenheit .
// Please give me the temperature in degrees celcius (a whole number).
//  100
// The temperature 100 degrees celcius is 212 degrees fahrenheit (rounded down to nearest whole number)
// I convert temperatures from degrees celcius to degrees fahrenheit .
// Please give me the temperature in degrees celcius (a whole number).
//  124
// The temperature 124 degrees celcius is 255 degrees fahrenheit (rounded down to nearest whole number)
// I convert temperatures from degrees celcius to degrees fahrenheit .
// Please give me the temperature in degrees celcius (a whole number).
//  -73
// ...

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %%
/* ***************************************************
    This program converts temperatures in celcius to
    fahrenheit.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022

*/

import java.util.Scanner;

class CelciusToFahrenheit
{

    public static void main(String[] param)
    {
        celciusToFahrenheit();
        
        return;
    }
    
    public static void celciusToFahrenheit()
    {
        Scanner scanner = new Scanner(System.in);
        
        int celcius; 
        int fahrenheit;       
        
        //  Get the temperature in fahrenheit as an integer
        
        System.out.println("I convert temperatures from degrees celcius to degrees fahrenheit .");
        System.out.println("Please give me the temperature in degrees celcius (a whole number).");
        celcius = Integer.parseInt(scanner.nextLine());
        
        // Now do the calculation of the total age
        //
        fahrenheit = ((celcius * 9) / 5) + 32;
        
        // Finally give the user the answer
        //   
        System.out.println("The temperature " + celcius + " degrees celcius is " + 
                           fahrenheit + " degrees fahrenheit (rounded down to nearest whole number)");
        return;  
    } // END celciusToFahrenheit
    
}

// %% [markdown]
// [Return to Exercise](#Exercise3)

// %%
### Solution to Exercise 4<a id="Solution4"></a>
// Out:
// |   ### Solution to Exercise 4<a id="Solution4"></a>
// illegal character: '#'
//
// |   ### Solution to Exercise 4<a id="Solution4"></a>
// illegal character: '#'
//
// |   ### Solution to Exercise 4<a id="Solution4"></a>
// illegal character: '#'
//
// |   ### Solution to Exercise 4<a id="Solution4"></a>
// ';' expected

// %%
 /* ***************************************************
    Given a user's age and the current year, it says what 
    year they were born (down to two possibilities).
    
     It only works if current year is correct
     or the person gives their age in that year.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022

*/

    
// This method gets a single integer age from the user 
// and returns it
//
public static int inputAge()
{
    Scanner scanner = new Scanner(System.in);
    int age;

    System.out.println("Tell me your age ");
    age = Integer.parseInt(scanner.nextLine());
   
    return age;
} // END inputAge

//    This method gets a single integer year from the user 
//    and returns it
//
public static int inputYear()
{
    Scanner scanner = new Scanner(System.in);
    int year;

    System.out.println("What year is it? ");
    year = Integer.parseInt(scanner.nextLine());
   
    return year;
} // END inputYear

    
//       This method asks the user their age and the 
//       current year and works out their
//       year of birth.
//       It only works if current year is correct
//       or the person gives their age in that year.
//
public static void bornGivenYear()
{
    int currentyear;
    int age;          
    int year;        
    String answertext;  // construct the text to give the answer back 
       
    // Get an age (a string) from the user then
    // convert (known as parsing) it into a number version
    // Do the same for the year
    //
    age = inputAge();
    currentyear = inputYear();

    // Now do the calculation
    //
    year = currentyear - age; 
    answertext = "You must have been born in " + year + " or " + (year - 1); 

    // Finally give the user the answer
    //   
    System.out.println(answertext);
       
    return;
} // END bornGivenYear

// %%
// Test the above program
// 1, 2000 -> 1999 or 2000
// 18,2022 -> 2004 or 2003
// 100, 2100 -> 2000 or 1999
bornGivenYear();
bornGivenYear();
bornGivenYear();
// Out:
// Tell me your age
//  1
// What year is it?
//  2000
// You must have been born in 1999 or 1998
// Tell me your age
//  18
// What year is it?
//  2022
// You must have been born in 2004 or 2003
// Tell me your age
//  100
// What year is it?
//  2100
// You must have been born in 2000 or 1999

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %%
 /* ***************************************************
    Given a user's age and the current year, it says what 
    year they were born (down to two possibilities).
    
     It only works if current year is correct
     or the person gives their age in that year.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022

*/

import java.util.Scanner;

class BornGivenYear
{

    public static void main(String[] param)
    {
        bornGivenYear();
        
        return;
    }
    
    // This method gets a single integer age from the user 
    // and returns it
    //
    public static int inputAge()
    {
        Scanner scanner = new Scanner(System.in);
        int age;

        System.out.println("Tell me your age ");
        age = Integer.parseInt(scanner.nextLine());
   
        return age;
    } // END inputAge

    //    This method gets a single integer year from the user 
    //    and returns it
    //
    public static int inputYear()
    {
        Scanner scanner = new Scanner(System.in);
        int year;

        System.out.println("What year is it? ");
        year = Integer.parseInt(scanner.nextLine());
   
        return year;
    } // END inputYear

    
    //       This method asks the user their age and the 
    //       current year and works out their
    //       year of birth.
    //       It only works if current year is correct
    //       or the person gives their age in that year.
    //
    public static void bornGivenYear()
    {
        int currentyear;
        int age;          
        int year;        
        String answertext;  // construct the text to give the answer back 
       
        // Get an age (a string) from the user then
        // convert (known as parsing) it into a number version
        // Do the same for the year
        //
        age = inputAge();
        currentyear = inputYear();

        // Now do the calculation
        //
        year = currentyear - age; 
        answertext = "You must have been born in " + year + " or " + (year - 1); 

        // Finally give the user the answer
        //   
        System.out.println(answertext);
       
        return;
    } // END bornGivenYear
    
}

// %% [markdown]
// [Return to Exercise](#Exercise4)

// %% [markdown]
// ### Solution to Exercise 5<a id="Solution5"></a>

// %%
/* ***************************************************
    This program takes the length and width of a
    rectangle (in cm) and computes its area
    
    AUTHOR Paul Curzon
    DATE 19 September 2022
*/


    //    This method gets a single integer length in cm from the user 
    //    and returns it
    //
    public static int inputLength()
    {
        Scanner scanner = new Scanner(System.in);
        int length;

        System.out.println("What is the length of the rectangle in cm? ");
        length = Integer.parseInt(scanner.nextLine());
   
        return length;
    } // END inputLength


    //    This method gets a single integer width in cm from the user 
    //    and returns it
    //
    public static int inputWidth()
    {
        Scanner scanner = new Scanner(System.in);
        int width;

        System.out.println("What is the width of the rectangle in cm?  ");
        width = Integer.parseInt(scanner.nextLine());
   
        return width;
    } // END inputWidth


    //       This method asks the user the length and width 
    //       of a rectangle in cm and works out its area.
    //
    public static void areaOfRectangle()
    {
        int length; 
        int width;
        int area;
        
        // Get the length and width from the user 
        //
        length = inputLength();
        width = inputWidth();

        // Now do the calculation
        //
        area = length * width; 

        // Finally give the user the answer
        //   
        System.out.println("The area of a rectangle of sides " + length + "cm and " + width + "cm is "
                       + area + "cm squared");
        System.out.println();
       
        return;
    } // END areaOfRectangle

// %%
// 10, 6 -> 60
// 2, 2 -> 4
// 0,0 -> 0
    
areaOfRectangle();
areaOfRectangle();
areaOfRectangle();
// Out:
// What is the length of the rectangle in cm?
//  10
// What is the width of the rectangle in cm?
//  6
// The area of a rectangle of sides 10cm and 6cm is 60cm squared
//
// What is the length of the rectangle in cm?
//  2
// What is the width of the rectangle in cm?
//  2
// The area of a rectangle of sides 2cm and 2cm is 4cm squared
//
// What is the length of the rectangle in cm?
//  0
// What is the width of the rectangle in cm?
//  0
// The area of a rectangle of sides 0cm and 0cm is 0cm squared

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %%
/* ***************************************************
    This program takes the length and width of a
    rectangle (in cm) and computes its area
    
    AUTHOR Paul Curzon
    DATE 19 September 2022
*/


import java.util.Scanner;

class AreaOfRectangle
{

    public static void main(String[] param)
    {
        areaOfRectangle();
        
        return;
    }

    //    This method gets a single integer length in cm from the user 
    //    and returns it
    //
    public static int inputLength()
    {
        Scanner scanner = new Scanner(System.in);
        int length;

        System.out.println("What is the length of the rectangle in cm? ");
        length = Integer.parseInt(scanner.nextLine());
   
        return length;
    } // END inputLength


    //    This method gets a single integer width in cm from the user 
    //    and returns it
    //
    public static int inputWidth()
    {
        Scanner scanner = new Scanner(System.in);
        int width;

        System.out.println("What is the width of the rectangle in cm?  ");
        width = Integer.parseInt(scanner.nextLine());
   
        return width;
    } // END inputWidth


    //       This method asks the user the length and width 
    //       of a rectangle in cm and works out its area.
    //
    public static void areaOfRectangle()
    {
        int length; 
        int width;
        int area;
        
        // Get the length and width from the user 
        //
        length = inputLength();
        width = inputWidth();

        // Now do the calculation
        //
        area = length * width; 

        // Finally give the user the answer
        //   
        System.out.println("The area of a rectangle of sides " + length + "cm and " + width + "cm is "
                       + area + "cm squared");
        System.out.println();
       
        return;
    } // END areaOfRectangle

}

// %% [markdown]
// [Return to Exercise](#Exercise5)

// %% [markdown]
// ### Solution to Exercise 6<a id="Solution6"></a>

// %%
/* ***************************************************
    This program takes the length and width of a
    rectangle (in cm) and computes its area.
    The details are stored in a Rectangle record.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022
*/


// Create a record type to hold Rectangle details
//
class Rectangle
{
    int length;
    int width;
}


    //        This method gets a single integer length in cm from the user 
    //        and returns it
    //
    public static int inputLength()
    {
        Scanner scanner = new Scanner(System.in);
        int length;
    
        System.out.println("What is the length of the rectangle in cm? ");
        length = Integer.parseInt(scanner.nextLine());
   
        return length;
    } // END inputLength


    //        This method gets a single integer width in cm from the user 
    //        and returns it
    //
    public static int inputWidth()
    {
        Scanner scanner = new Scanner(System.in);
        int width;

        System.out.println("What is the width of the rectangle in cm?  ");
        width = Integer.parseInt(scanner.nextLine());
   
        return width;
    } // END inputWidth


    //       This method asks the user the length and width 
    //       of a rectangle in cm and works out its area.
    //
    public static void areaOfRectangleFromRecord()
    {
        Rectangle rect = new Rectangle();
        int area;
        
        // Get the length and width from the user 
        //
        rect.length = inputLength();
        rect.width = inputWidth();

        // Now do the calculation
        //
        area = rect.length * rect.width; 

        // Finally give the user the answer
        //   
        System.out.println("The area of a rectangle of sides " + rect.length + "cm and " +
                       rect.width + "cm is " + area + "cm squared");
        System.out.println();
       
        return;
    } // END areaOfRectangleFromRecord

// %%
// 10, 6 -> 60
// 2, 2 -> 4
// 0,0 -> 0
    
areaOfRectangleFromRecord();
areaOfRectangleFromRecord();
areaOfRectangleFromRecord();
// Out:
// What is the length of the rectangle in cm?
//  10
// What is the width of the rectangle in cm?
//  6
// The area of a rectangle of sides 10cm and 6cm is 60cm squared
//
// What is the length of the rectangle in cm?
//  2
// What is the width of the rectangle in cm?
//  2
// The area of a rectangle of sides 2cm and 2cm is 4cm squared
//
// What is the length of the rectangle in cm?
//  0
// What is the width of the rectangle in cm?
//  0
// The area of a rectangle of sides 0cm and 0cm is 0cm squared

// %%
/* ***************************************************
    This program takes the length and width of a
    rectangle (in cm) and computes its area.
    The details are stored in a Rectangle record.
    
    AUTHOR Paul Curzon
    DATE 19 September 2022
*/


import java.util.Scanner;

// Create a record type to hold Rectangle details
//
class Rectangle
{
    int length;
    int width;
}

class AreaOfRectangleFromRecord
{

    public static void main(String[] param)
    {
        areaOfRectangleFromRecord();
        
        return;
    }

    //        This method gets a single integer length in cm from the user 
    //        and returns it
    //
    public static int inputLength()
    {
        Scanner scanner = new Scanner(System.in);
        int length;
    
        System.out.println("What is the length of the rectangle in cm? ");
        length = Integer.parseInt(scanner.nextLine());
   
        return length;
    } // END inputLength


    //        This method gets a single integer width in cm from the user 
    //        and returns it
    //
    public static int inputWidth()
    {
        Scanner scanner = new Scanner(System.in);
        int width;

        System.out.println("What is the width of the rectangle in cm?  ");
        width = Integer.parseInt(scanner.nextLine());
   
        return width;
    } // END inputWidth


    //       This method asks the user the length and width 
    //       of a rectangle in cm and works out its area.
    //
    public static void areaOfRectangleFromRecord()
    {
        Rectangle rect = new Rectangle();
        int area;
        
        // Get the length and width from the user 
        //
        rect.length = inputLength();
        rect.width = inputWidth();

        // Now do the calculation
        //
        area = rect.length * rect.width; 

        // Finally give the user the answer
        //   
        System.out.println("The area of a rectangle of sides " + rect.length + "cm and " +
                       rect.width + "cm is " + area + "cm squared");
        System.out.println();
       
        return;
    } // END areaOfRectangleFromRecord
    
}

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %% [markdown]
// [Return to Exercise](#Exercise6)

// %% [markdown]
// ### Solution to Exercise 7<a id="Solution7"></a>

// %%
/* ***************************************************
    This program is given the profit a company made and 
    shares it between 5 employees.
    Answers are only accurate to nearest pound
    
    AUTHOR Paul Curzon
    DATE 24 September 2022
*/
    
//    This method gets a single integer profit in pounds from the user 
//    and returns it
//
public static int inputProfit()
{
    Scanner scanner = new Scanner(System.in);
    int profit;

    System.out.println("What is the company profit (in a whole number of pounds)? ");
    profit = Integer.parseInt(scanner.nextLine());
                           
    return profit;
} // END inputLength


//       This method asks the user the length and width 
//       of a rectangle in cm and works out its area.
//
public static void shareOutProfit()
{
    int profit_in_pounds;
    int profit_each;
    final int EMPLOYEES = 5;
    
    // Get the profit from the user 
    //
    profit_in_pounds = inputProfit();

    // Now do the calculation
    //
    profit_each = profit_in_pounds/EMPLOYEES; 

    // Finally give the user the answer
    //   
    System.out.println("Each of the " + EMPLOYEES + " employees gets " + 
                           profit_each + " pounds each.");
    System.out.println();
       
    return;
} // END shareOutProfit

// %%
// Test above
// 0 -> 0
// 5000 -> 1000
// 10000000 -> 2000000
// 4000 -> 800
// 8 -> 1
shareOutProfit();
shareOutProfit();
shareOutProfit();
shareOutProfit();
shareOutProfit();
// Out:
// What is the company profit (in a whole number of pounds)?
//  0
// Each of the 5 employees gets 0 pounds each.
//
// What is the company profit (in a whole number of pounds)?
//  5000
// Each of the 5 employees gets 1000 pounds each.
//
// What is the company profit (in a whole number of pounds)?
//  10000000
// Each of the 5 employees gets 2000000 pounds each.
//
// What is the company profit (in a whole number of pounds)?
//  4000
// Each of the 5 employees gets 800 pounds each.
//
// What is the company profit (in a whole number of pounds)?
//  8
// Each of the 5 employees gets 1 pounds each.

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %%
/* ***************************************************
    This program is given the profit a company made and 
    shares it between 5 employees.
    Answers are only accurate to nearest pound
    
    AUTHOR Paul Curzon
    DATE 24 September 2022
*/


import java.util.Scanner;

class ShareOutProfit
{

    public static void main(String[] param)
    {
        shareOutProfit();
        
        return;
    }
    
    //    This method gets a single integer profit in pounds from the user 
    //    and returns it
    //
    public static int inputProfit()
    {
        Scanner scanner = new Scanner(System.in);
        int profit;

        System.out.println("What is the company profit (in a whole number of pounds)? ");
        profit = Integer.parseInt(scanner.nextLine());
   
        return profit;
    } // END inputLength


    //       This method asks the user the length and width 
    //       of a rectangle in cm and works out its area.
    //
    public static void shareOutProfit()
    {
        int profit_in_pounds;
        int profit_each;
        final int EMPLOYEES = 5;
    
        // Get the profit from the user 
        //
        profit_in_pounds = inputProfit();

        // Now do the calculation
        //
        profit_each = profit_in_pounds/EMPLOYEES; 

        // Finally give the user the answer
        //   
        System.out.println("Each of the " + EMPLOYEES + " employees gets " + 
                           profit_each + " pounds each.");
        System.out.println();
       
        return;
    } // END shareOutProfit
    
}

// %% [markdown]
// Decimal numbers are a different type to integers. Integers are not accurate when you eg do division as everything is converted to a whole number. Use type keyword double (for double length floating point number).

// %% [markdown]
// [Return to Exercise](#Exercise7)

// %% [markdown]
// ### Solution to Exercise 8<a id="Solution8"></a>
//
// We have added to this a commented out line that shows a new way to print that formats numbers
// controlling the number of decimal places printed.
//
// ```
// System.out.format("Each of the %.0f employees gets %.2f pounds each.",
//                   EMPLOYEES, profit_each);
// ```
// The method ```System.out.format``` takes a String argument that now has formatting instructions in it that control where to print the value of variables and how many decimal places are printed.
// The positions of variables are now indicated by a code starting with a %. %.0f means print the decimal number with no decimal places printed. %.2f means print the decimal number with two decimal places printed. The variables whose values are to be printed appear after the String and are used in  the positions of the String in order.
//
// Run it as is and then edit the comment symbol out to see what this format command does differently.

// %%
/* ***************************************************
    This program is given the profit a company made and 
    shares it between 5 employees.
    Answers are in this version accurate to pence
    With commented out code that prints out the answer in a more appropriate format.
    
    AUTHOR Paul Curzon
    DATE 24 September 2022
*/


//    This method gets a single integer profit in pounds from the user 
//    and returns it
//
public static int inputProfit()
{
    Scanner scanner = new Scanner(System.in);
    int profit;

    System.out.println("What is the company profit (in a whole number of pounds)? ");
    profit = Integer.parseInt(scanner.nextLine());
   
    return profit;
} // END inputLength


//       This method asks the user the length and width 
//       of a rectangle in cm and works out its area.
//
public static void shareOutProfitAccurate()
{
    double profit_in_pounds;
    double profit_each;
    final double EMPLOYEES = 5.0;
    
    // Get the profit from the user 
    //
    profit_in_pounds = (double) inputProfit();

    // Now do the calculation
    //
    profit_each = profit_in_pounds/EMPLOYEES; 

    // Finally give the user the answer
    //   
    System.out.println("Each of the " + EMPLOYEES + " employees gets £" + 
                       profit_each + " each.");
    //  System.out.format("Each of the %.0f employees gets £%.2f each.",
    //                   EMPLOYEES, profit_each);
    System.out.println();
       
    return;
} // END shareOutProfit

// %%
// Test above
// 0 -> 0.0
// 5000 -> 1000.0
// 11 -> 2.2
// 1234 -> 246.8
// 8 -> 1.6
shareOutProfitAccurate();
shareOutProfitAccurate();
shareOutProfitAccurate();
shareOutProfitAccurate();
shareOutProfitAccurate();
// Out:
// What is the company profit (in a whole number of pounds)?
//  0
// Each of the 5.0 employees gets £0.0 each.
//
// What is the company profit (in a whole number of pounds)?
//  5000
// Each of the 5.0 employees gets £1000.0 each.
//
// What is the company profit (in a whole number of pounds)?
//  11
// Each of the 5.0 employees gets £2.2 each.
//
// What is the company profit (in a whole number of pounds)?
//  1234
// Each of the 5.0 employees gets £246.8 each.
//
// What is the company profit (in a whole number of pounds)?
//  8
// Each of the 5.0 employees gets £1.6 each.

// %% [markdown]
// Below is a full Java program version as you would run externally from your desktop

// %%
/* ***************************************************
    This program is given the profit a company made and 
    shares it between 5 employees.
    
    Answers are in this version accurate to pence
    With commented out code that prints out the answer in a more appropriate format.
    
    AUTHOR Paul Curzon
    DATE 24 September 2022
*/


import java.util.Scanner;

class ShareOutProfitAccurate
{

    public static void main(String[] param)
    {
        shareOutProfitAccurate();
        
        return;
    }
    
    //    This method gets a single integer profit in pounds from the user 
    //    and returns it
    //
    public static int inputProfit()
    {
        Scanner scanner = new Scanner(System.in);
        int profit;

        System.out.println("What is the company profit (in a whole number of pounds)? ");
        profit = Integer.parseInt(scanner.nextLine());
   
        return profit;
    } // END inputLength


    //       This method asks the user the length and width 
    //       of a rectangle in cm and works out its area.
    //
    public static void shareOutProfitAccurate()
    {
        double profit_in_pounds;
        double profit_each;
        final double EMPLOYEES = 5.0;
    
        // Get the profit from the user 
        //
        profit_in_pounds = (double) inputProfit();

        // Now do the calculation
        //
        profit_each = profit_in_pounds/EMPLOYEES; 

        // Finally give the user the answer
        //   
        System.out.println("Each of the " + EMPLOYEES + " employees gets £" + 
                           profit_each + " each.");
        //  System.out.format("Each of the %.0f employees gets £%.2f each.",
        //                   EMPLOYEES, profit_each);
        System.out.println();
       
        return;
    } // END shareOutProfitAccurate

}

// %% [markdown]
// [Return to Exercise](#Exercise8)
