// %% [markdown]
// # Unit 2 Part 4: Good Basic Style - Final Variables
//
// ## Paul Curzon
//
// ## Interactive Programming Exercises
//
// ### Learning Outcomes
// - Explain how final variables can both improve readability and help avoid bugs.
// - Write programs that use final variables
//
//
// *This notebook looks at code fragments. After completing these exercises you MUST then go on to write full programs - see the programming exercises in the workbook.*
//
// *Answers to exercises are given at the end*
//
// **Always read the answers to exercises and compare them to your own. There are important things to learn from the answers.**
//
// <span style="color: red;"> It is a really good idea to add your own notes throughout this notebook to reinforce what you have learnt and highlight important points. Click on the + in the toolbar above to make a new note area, and change it from Code to Markdown in the dropdown menu above if your note is not executable code. You may also want to highlight your notes in red as here, so they stand out. You change colours using span like this: </span>
// ```
// <span style="color: red;">THE TEXT TO COLOUR RED</span>
// ```

// %% [markdown]
// ## Introduction
// Good style is about writing code in a way that makes it easier to read and so understand and so both get right originally as well as modify without introducing mistakes later.
//
// Here we look at how variables contribute to readability.
//
// There are lots of aspects to good style but the basics are:
// - write useful comments, not too many, not too few
// - indent your code and line up curly brackets
// - use blank lines to make separate blocks or methods stand out as separate
// - choose good, meaningful variable names
// - choose good meaningful method names
// - use final variables for literal values
//
// More sophisticated forms of good style that are critical to making code readable are good: decomposition (breaking a program into methods corresponding to sub-tasks), generalisation (writing general methods that can be used for several related tasks) and abstraction (hiding the detail of things so you can focus on what is important with the coding task at hand). The use of these form the foundation of what is meant by computational thinking.

// %% [markdown]
// **In this notebook we focus on final variables.**

// %% [markdown]
// ## Naming literal values

// %% [markdown]
// *Literal* values are just actual values that appear in your code  like 100 or 12000 or 0.5. It is often a good idea to replace literal values with variables, particularly when it is a number that means something. This gives that number a name and if that name is well chosen can make clear the value's meaning.
//
// Here is an example from school. Suppose you want to work out the perimeter of a regular Octagon. The building called The Octagon at QMUL is octagonal in shape, for example. The perimeter is just how far you would have to walk if you were to walk round its edges.  As all the sides are the same (that's what it means for it to be regular) and an octagon has 8 sides, the perimeter is just 8 times the side length.
//
// The following method calculates this for us for any side length we give it. Read it and make sure you understand it.

// %%
// Calculate the perimeter of a regular octagon
//
public static int perimeterOfOctagon1 (int side_length)
{
    return 8 * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfOctagon1 (1) );
System.out.println( perimeterOfOctagon1 (3) );

// %% [markdown]
// However, as in our description that number 8 in the method has a meaning - it is the number of sides. That is why we are multiplying by 8 rather than 6 or 21. So it makes clearer what the method is calculating if we actually call it by a meaningful name e.g. OCTAGON_NUMBER_OF_SIDES, as in the following better version of the same method.

// %%
// Calculate the perimeter of a regular octagon
//
public static int perimeterOfOctagon2 (int side_length)
{
    int OCTAGON_NUMBER_OF_SIDES = 8;
    
    return OCTAGON_NUMBER_OF_SIDES * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfOctagon2 (1) );
System.out.println( perimeterOfOctagon2 (3) );

// %% [markdown]
// Now we have made it absolutely clear that that number is meant to be the number of sides of an octagon.
//
// It is a good idea to write variables that represent unchanging values like this in all capitals as we have done here. That gives you a visual reminder when reading the program that they do not change.

// %% [markdown]
// ### Exercise 1<a id="Exercise1"></a>
//
// Complete the following method that is intended to calculate the perimeter of a regular hexagon given the length of its sides. Hexagons have 6 sides.

// %%
// Calculate the perimeter of a regular hexagon
//
public static int perimeterOfHexagon1 (int side_length)
{
 
}

// %%
// Test above method
System.out.println( perimeterOfHexagon1 (1) ); // should give answer 6
System.out.println( perimeterOfHexagon1 (3) ); // should give answer 18

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution1)

// %% [markdown]
// ### Exercise 2<a id="Exercise2"></a>
//
// Complete the following method that is intended to calculate the circumference of a circle given its diameter. The circumference of a circle is like the perimeter of a regular shape - the distance round it. It is obtained by multiplying the diameter by PI where PI is the number 3.14. Use a variable for PI. Note that PI is not an integer so both it and the answer will need to be type double.

// %%
// Calculate the circumference of a circle given its diameter
//
public static double circumferenceOfCircle1 (int diameter)
{

}

// %%
// Test above method
System.out.println( circumferenceOfCircle1 (1) ); // should give answer 3.14
System.out.println( circumferenceOfCircle1 (3) ); // should give answer 9.42

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution2)

// %% [markdown]
// ## Final Variables ##
//
// We can do better than this though, by using final variables. Final variables are just variables that have been declared to never change. They represent constant values. They can be initialised but never then changed. No assignment is allowed after the first one. Any variable that is being used to represent a constant literal value like this should be declared final. The program works exactly the same. It just makes it clear that that variable is never intended to change.
//
// You do this by simply putting the keyword *final* in front of the declaration, so if you were declaring a variable representing the teams in a knockout competition to be 64 as
//
// int NUMBER_OF_TEAMS = 64;
//
// then you would instead write
//
// final int NUMBER_OF_TEAMS = 64;
//
// A better version of our method to calculate the perimeter of an octagon would use a final variable like this. Notice the use of the keyword final in the method below.

// %%
// Calculate the perimeter of a regular octagon
//
public static int perimeterOfOctagon3 (int side_length)
{
    final int OCTAGON_NUMBER_OF_SIDES = 8;
    
    return OCTAGON_NUMBER_OF_SIDES * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfOctagon3  (1) ); // should give answer 8
System.out.println( perimeterOfOctagon3  (3) ); // should give answer 24

// %% [markdown]
// ### Exercise 3<a id="Exercise3"></a>
//
// Improve this method to calculate the perimeter of a hexagon using a final variable.

// %%
// Calculate the perimeter of a regular octagon
//
public static int perimeterOfHexagon2 (int side_length)
{
    int HEXAGON_NUMBER_OF_SIDES = 6;
    
    return HEXAGON_NUMBER_OF_SIDES * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfHexagon2 (1) );  // should give answer 6
System.out.println( perimeterOfHexagon2 (3) );  // should give answer 8

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution3)

// %% [markdown]
// ### Exercise 4<a id="Exercise4"></a>
//
// Improve this method to calculate the circumference of a circle by using a final variable.

// %%
// Calculate the circumference of a circle given its diameter
//
public static double circumferenceOfCircle2 (int diameter)
{
    double PI = 3.14;
    
    return PI * diameter;
}

// %%
// Test above method
System.out.println( circumferenceOfCircle2 (1) ); // should give answer 3.14
System.out.println( circumferenceOfCircle2 (3) ); // should give answer 9.42

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution4)

// %% [markdown]
// ### Exercise 5<a id="Exercise5"></a>
//
// Suppose you are writing a game program that involves people travelling between different planets. While a person's mass stays the same, their weight (and how quickly they fall) depends on the strength of the gravity of the planet they are on. You work out the weight of an object by *multiplying its mass by a constant called the gravitational field strength of that planet*.
//
// Complete the method in the box below to work out the weight of objects on Mars given their mass in kg. The gravitational field strength on Mars is 3.7 N/kg. Use a final variable for the gravitational field strength.

// %%
// Calculate the weight of objects on Mars given their mass in Kg
//
public static double weightOnMars (int mass)
{
 
}

// %%
// Test above method
System.out.println( weightOnMars (10) ); // should give answer 37.0
System.out.println( weightOnMars (64) ); // should give answer 236.8

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution5)

// %% [markdown]
// ## Why use final variables ##
//
// ### Improving readability, Spotting mistakes ###
// Final variables improve readability because they make clear the meaning of numbers in each context they are used. By using final variables, we are also giving information to the compiler that can help it spot mistakes we make. The compiler has been told that the final variable should not change. Therefore if you write an assignment that tries to change it, then the compiler can warn you that this is a mistake.  This makes the mistake an easy to spot compile-time error instead of it being a hard to spot run time error. Run-time errors may never be detected and in end up in production programs. With a compile time error, you do not have a program at all to run as the compiler refuses to compile it.

// %% [markdown]
// ### Exercise 6<a id="Exercise6"></a>
//
// Compile/Run the following method and its test call to calculate the perimeter of a regular pentagon (a five sided shape). We adapted it from one of our earlier methods before we started using final variables. Does it work? If not why not.

// %%
// Calculate the perimeter of a regular ppentagon
//
public static int perimeterOfPentagon1 (int side_length)
{    
    return 8 * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfPentagon1 (10) ); 
System.out.println( perimeterOfPentagon1 (64) );

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution6)

// %% [markdown]
// The above program is faulty and the mistake is hard to spot unless we know the maths behind calculating perimeters, so understand why the number is the value it is. Final variables give meaning to numbers and that can make it easier to realise there is a mistake as in this similarly incorrect version.

// %%
// Calculate the perimeter of a regular ppentagon
//
public static int perimeterOfPentagon2 (int side_length)
{  
    final int PENTAGON_NUMBER_OF_SIDES = 8;

    return PENTAGON_NUMBER_OF_SIDES * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfPentagon2 (10) ); 
System.out.println( perimeterOfPentagon2 (64) );

// %% [markdown]
// This is still wrong, but the mistake is easier to spot. You only need to know that pentagons do not have 8 sides to realise something is odd. You do not need to understand the maths of calculating perimeters.
//
// The use of final variables makes code easier to understand and can help make mistakes easier to spot during a code walkthrough where the code is checked. It can also help the programmer avoid making mistakes as the above focuses their attention on what that number means as they write the code.

// %% [markdown]
// ### Exercise 7<a id="Exercise7"></a>
//
// Compile/Run the following method to calculate and print the area and circumference of a circle. Then run  the test. Does it work? If not why not?

// %%
// Print the area AND circumference of a circle given its radius
//
public static void printAreaCircumferenceOfCircle1 (int radius)
{
    double PI = 3.14;
    
    System.out.println("The area is " + PI * radius * radius);
    PI = 3.1;   
    System.out.println("The circumference is " + 2 * PI * radius);
    
    return;    
}

// %%
// Test the above method
printAreaCircumferenceOfCircle1 (12);

// %% [markdown]
// ** Write your answer here **

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution7)

// %% [markdown]
// If this were part of a large program, we may or may not spot the mistake. Here is is only in a few lines so possibly we would, but imagine if it were in a program ten thousand lines long, in a method doing a much trickier calculation. The compiler certainly cannot help us find it. There is therefore a chance that it will never be spotted. Similar mistakes have gone undetected and cost millions of pounds as a result.

// %% [markdown]
// ### Exercise 8<a id="Exercise8"></a>
//
// Compile/Run the following improved  (but still incorrect) method to calculate and print the area and circumference of a circle. How easy is it this time to see that it contains a bug? Correct it by commenting out the faulty line of code.

// %%
// Print the area AND circumference of a circle given its radius
//
public static void printAreaCircumferenceOfCircle2 (int radius)
{
    final double PI = 3.14;
    
    System.out.println("The area is " + PI * radius * radius);
    PI = 3.1;   
    System.out.println("The circumference is " + 2 * PI * radius);
    
    return;    
}

// %%
// Test the above method
printAreaCircumferenceOfCircle2 (12);

// %% [markdown]
// ** Write your answer here **

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution8)

// %% [markdown]
// What this shows is that by using final variables, we have given the compiler more information about our intentions as a programmer. When we created the variable PI we did so intending it to never be changed as it is supposed to be a constant. If we make a mistake and add a line that changes the value, the compiler knows we have made a mistake and can tell us. Either we did not intend it to be unchanged so making it final was a mistake, or it is a mistake to change it. Either way we are alerted immediately and do not have a program to run until we have fixed the problem.
//
// We have changed a hard to find run time error into an impossible to miss compile time error.

// %% [markdown]
// ### Making changes ###
//
// Another reason for using final variables is that it makes it easier to make changes without introducing mistakes. This might be to make a constant like pi and so our program more accurate, or just because some requirement of the program has changed.
//
// For example, suppose you are writing code to help control a chocolate factory production line. Small bars are made of 8 triangles of chocolate and big bars are made of 16 triangles of chocolate with the triangles themselves the same size: each triangle is made of 12g of chocolate  We might write a method like this to do the calculations for us.

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 12g
//
public static void amountOfChocolate1()
{
    int small = 12 * 8;
    int big = 12 * 16;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate1();

// %% [markdown]
// As we have already seen having all these numbers makes the code hard to read, hard to understand. It would be easy to get them confused. If we needed to reduce the number of triangles in a big bar (to make them cheaper) we could easily change the wrong number. Similarly, it is better to avoid making changes in multiple places.

// %% [markdown]
// ### Exercise 9<a id="Exercise9"></a>
// Suppose we are required (due to government attempts to reduce obesity) to shrink all chocolate bars, so change the size of the triangles in our bars to consist of less chocolate each.
//
// Modify the code below so that each triangle only uses 9g of chocolate. Don't forget to change the comment too.

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 12g
//
public static void amountOfChocolate2()
{
    int small = 12 * 8;
    int big = 12 * 16;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate2();

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution9)

// %% [markdown]
// You could easily change the wrong value or only one value of the two occurences by mistake, or change them to different values by mistake. In any case to do that here would involve making two changes and the fewer changes you have to make the better.

// %% [markdown]
// ### Exercise 10<a id="Exercise10"></a>
//
// Modify the improved code below so that each triangle only uses 9g of chocolate.  Don't forget to change the comment too. How many changes do you need to make?

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 12g
//
public static void amountOfChocolate3()
{
    final int CHOCOLATE_PER_TRIANGLE = 12;
    final int TRIANGLES_IN_SMALL_BAR = 8;
    final int TRIANGLES_IN_BIG_BAR = 16;
    
    int small = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_SMALL_BAR;
    int big = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_BIG_BAR;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate3();

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution10)

// %% [markdown]
// ### Exercise 11<a id="Exercise11"></a>
//
// Now consider this version where triangles use 8g of chocolate. The company decides the country needs a treat. Change it to use 10g per triangle instead of 8g.

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 8g
//
public static void amountOfChocolate4()
{
    int small = 8 * 8;
    int big = 8 * 16;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate4();

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution11)

// %% [markdown]
// ### Exercise 12<a id="Exercise12"></a>
//
// The better version with final variables is easier to change and be sure you have done so correctly because every value is named. Change it to use 10g per triangle instead of 8g.

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 8g
//
public static void amountOfChocolate5()
{
    final int CHOCOLATE_PER_TRIANGLE = 8;
    final int TRIANGLES_IN_SMALL_BAR = 8;
    final int TRIANGLES_IN_BIG_BAR = 16;
    
    int small = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_SMALL_BAR;
    int big = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_BIG_BAR;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate5();

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution12)

// %% [markdown]
// It would be very easy to get confused and just change all the 8 s to 10, introducing a hard to spot bug (especially if you decided to take a short cut and just do an automatic global replace of 8 for 10 using an editor.

// %% [markdown]
// ### Exercise 13<a id="Exercise13"></a>
//
// **Summarise** the main advantages of final variables.

// %% [markdown]
// ** Write your answer here **

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution13)

// %% [markdown]
// *Once you have done the above exercises (and understand how the concepts work) move on to doing the actual programming exercises from the handbook, writing full programs. You must be able to write full programs, not just fragments.*

// %% [markdown]
// ## Solutions
//
// ### Solution to Exercise 1<a id="Solution1"></a>

// %%
// Calculate the perimeter of a regular octagon
//
public static int perimeterOfHexagon1 (int side_length)
{
    int HEXAGON_NUMBER_OF_SIDES = 6;
    
    return HEXAGON_NUMBER_OF_SIDES * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfHexagon1 (1) ); // should give answer 6
System.out.println( perimeterOfHexagon1 (3) ); // should give answer 18

// %% [markdown]
// [Return to Exercise](#Exercise1)

// %% [markdown]
// ### Solution to Exercise 2<a id="Solution2"></a>

// %%
// Calculate the circumference of a circle given its diameter
//
public static double circumferenceOfCircle1 (int diameter)
{
    double PI = 3.14;
    
    return PI * diameter;
}

// %%
// Test above method
System.out.println( circumferenceOfCircle1 (1) ); // should give answer 3.14
System.out.println( circumferenceOfCircle1 (3) ); // should give answer 9.42

// %% [markdown]
// [Return to Exercise](#Exercise2)

// %% [markdown]
// ### Solution to Exercise 3<a id="Solution3"></a>

// %%
// Calculate the perimeter of a regular octagon
//
public static int perimeterOfHexagon2 (int side_length)
{
    final int HEXAGON_NUMBER_OF_SIDES = 6;
    
    return HEXAGON_NUMBER_OF_SIDES * side_length;
}

// %%
// Test above method
System.out.println( perimeterOfHexagon2 (1) );  // should give answer 6
System.out.println( perimeterOfHexagon2 (3) );  // should give answer 18

// %% [markdown]
// [Return to Exercise](#Exercise3)

// %% [markdown]
// ### Solution to Exercise 4<a id="Solution4"></a>

// %%
// Calculate the circumference of a circle given its diameter
//
public static double circumferenceOfCircle2 (int diameter)
{
    final double PI = 3.14;
    
    return PI * diameter;
}

// %%
// Test above method
System.out.println( circumferenceOfCircle2 (1) ); // should give answer 3.14
System.out.println( circumferenceOfCircle2 (3) ); // should give answer 9.42

// %% [markdown]
// [Return to Exercise](#Exercise4)

// %% [markdown]
// ### Solution to Exercise 5<a id="Solution5"></a>

// %%
// Calculate the weight of objects on Mars given their mass in Kg
//
public static double weightOnMars (int mass)
{
    final double MARS_GRAVITY = 3.7; // In N/Kg
        
    double weight_on_mars = MARS_GRAVITY * mass;
    
    return weight_on_mars;
}

// %%
// Test above method
System.out.println( weightOnMars (10) ); // should give answer 37.0 
System.out.println( weightOnMars (64) ); // should give answer 236.8

// %% [markdown]
// [Return to Exercise](#Exercise5)

// %% [markdown]
// ### Solution to Exercise 6<a id="Solution6"></a>

// %% [markdown]
// The code compiles and runs without apparent problem, but the answers it gives are wrong. There is a bug in the code that means its calculations are faulty. The programmer accidentally left the number represnting the number of sides as 8 as it was in the method this one was modified from. It should have been 5 as pentagons have 5 sides. The way the programmer wrote the method did not do so in a way that made it easy to spot.

// %% [markdown]
// [Return to Exercise](#Exercise6)

// %% [markdown]
// ### Solution to Exercise 7<a id="Solution7"></a>

// %% [markdown]
// This code also compiles and runs, giving incorrect answers (though they are nearly right so perhaps hard to spot).
//
// The value of PI used is inconsistent. One value (3.14) is used for the circumference but 3.1 is used before the area calculation as an assignment that changes its value has accidentally been included. The compiler has no way of knowing what was intended so cannot help.

// %% [markdown]
// [Return to Exercise](#Exercise7)

// %% [markdown]
// ### Solution to Exercise 8<a id="Solution8"></a>

// %% [markdown]
// This time the code does not even compile. The compiler is able to spot the error for you as it was given extra information that once set PI should not change. While such error messages are sometimes hard to follow and it still can take some time to realise what exactly you did wrong, they critically mean you do not have a working program, so no one can use it and get wrong results.
//
// The second assignment to PI needs to be deleted as below.

// %%
// Print the area AND circumference of a circle given its radius
//
public static void printAreaCircumferenceOfCircle2 (int radius)
{
    final double PI = 3.14;
    
    System.out.println("The area is " + PI * radius * radius);
    // PI = 3.1;  This line was a bug and should not have been included 
    System.out.println("The circumference is " + 2 * PI * radius);
    
    return;    
}

// %%
// Test the above method
printAreaCircumferenceOfCircle2 (12);

// %% [markdown]
// [Return to Exercise](#Exercise8)

// %% [markdown]
// ### Solution to Exercise 9<a id="Solution9"></a>

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 9g
//
public static void amountOfChocolate2()
{
    int small = 9 * 8;
    int big = 9 * 16;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate2();

// %% [markdown]
// [Return to Exercise](#Exercise9)

// %% [markdown]
// ### Solution to Exercise 10<a id="Solution10"></a>

// %% [markdown]
// Only one change is needed in this version and it guarantees to change the value everywhere and do so consistently.

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 9g
//
public static void amountOfChocolate3()
{
    final int CHOCOLATE_PER_TRIANGLE = 9;
    final int TRIANGLES_IN_SMALL_BAR = 8;
    final int TRIANGLES_IN_BIG_BAR = 16;
    
    int small = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_SMALL_BAR;
    int big = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_BIG_BAR;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate3();

// %% [markdown]
// [Return to Exercise](#Exercise10)

// %% [markdown]
// ### Solution to Exercise 11<a id="Solution11"></a>

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 10g
//
public static void amountOfChocolate4()
{
    int small = 10 * 8;
    int big = 10 * 16;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate4();

// %% [markdown]
// [Return to Exercise](#Exercise11)

// %% [markdown]
// ### Solution to Exercise 12<a id="Solution12"></a>

// %%
// Work out how much chocolate is needed to make small and big bars of chocolate
// Each triangle uses 10g
//
public static void amountOfChocolate5()
{
    final int CHOCOLATE_PER_TRIANGLE = 10;
    final int TRIANGLES_IN_SMALL_BAR = 8;
    final int TRIANGLES_IN_BIG_BAR = 16;
    
    int small = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_SMALL_BAR;
    int big = CHOCOLATE_PER_TRIANGLE * TRIANGLES_IN_BIG_BAR;
    
    System.out.println("A small bar needs " + small + "g of chocolate.");
    System.out.println("A big bar needs " + big + "g of chocolate.");
    
    return;
}

// %%
// Test the above method
amountOfChocolate5();

// %% [markdown]
// [Return to Exercise](#Exercise12)

// %% [markdown]
// ### Solution to Exercise 13<a id="Solution13"></a>

// %% [markdown]
// Final variables make code more readable for programmers making errors easier to spot, and give information to the compiler so it can catch certain kinds of errors. They also mean changes can be more easily made and done so in a way that avoids introducing inconsistencies.

// %% [markdown]
// [Return to Exercise](#Exercise13)
