// %% [markdown]
// # Unit 6 Part 2: While loops with complex conditions
//
// ## Paul Curzon
//
// ## Interactive Programming Exercises
//
// ### Learning Outcomes
// - Explain how to use while loops with more complex conditions that use logical connectives.
// - Write programs with more complex conditions using logical connectives
//
// *This notebook looks at code fragments. After completing these exercises you MUST then go on to write full programs - see the programming exercises in the workbook.*
//
// *Answers to exercises are given at the end*
//
// **Always read the answers to exercises and compare them to your own. There are important things to learn from the answers.**
//
// <span style="color: red;"> It is a really good idea to add your own notes throughout this notebook to reinforce what you have learnt and highlight important points. Click on the + in the toolbar above to make a new note area, and change it from Code to Markdown in the dropdown menu above if your note is not executable code. You may also want to highlight your notes in red as here, so they stand out. You change colours using span like this: </span>
// ```
// <span style="color: red;">THE TEXT TO COLOUR RED</span>
// ```

// %% [markdown]
// ## Introduction
// We have seen how **while** loops can control repetition in a way that the number of times the body of the loop is executed (the number of **iterations**) is unpredictable. While loops should be used whenever the number of iterations is unknown. A **for** loop, by contrast, is best used when the number of iterations of the loop is known when it starts.
//
// In particular, we have seen how we can write a while loop that keeps asking the user if they want to continue, and so keeps going until the user indicates that they want to stop.
//
// We have also seen how a while loop can actually do anything a for loop can do. In particular, you can write a counter- controlled loop using a while loop. However, counter-controlled loops are better written using a for loop as it immediately indicates to a reader that it *is* a counter-controlled loop so is easier to understand. Also, by pulling the three key parts of a counter-controlled loop into one line (initialising the counter, testing the counter and changing the counter), means they are less likely to be forgotten.
//
// Now, we look at how we can have more complex tests of when the for loop ends.

// %% [markdown]
// ### Exercise 1<a id="Exercise1"></a>
//
// Read the following code, which starts with a standard inputString method to read in String input from the keyboard. Explain what the method zombies1 does overall (not line by line). Then run it and check you were right.

// %%
// Allow a single film to be input, returning the film typed as the answer
//
public static String inputString (String message)
{
       String answer;
       Scanner scanner = new Scanner(System.in);

       System.out.println(message);
       answer = scanner.nextLine();
   
       return answer;
} // END inputString

// %%
// Warn of the coming zombie appocalypse
//
public static void zombies1 ()
{
       int count = 0;
       String answer = "HELP";
    
       while (answer.equals("HELP"))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear?");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %% [markdown]
// ** Write your explanation here **

// %%
// Test above method
zombies1 ();
// Out:
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear?
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear?
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear?
//  run
// You saw 3 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution1)

// %% [markdown]
// ## Logical Or (||) ##
//
// We have seen previously how we can write a condition for an if statement that is true if either one thing is true OR another thing is true. This is done using the logical OR connective (||). For example to test whether a variable monster was equal to zombie or the variable monster was equal to vampire we would write a test:
//
// ( monster.equals("zombie") || monster.equals("vampire") )

// %% [markdown]
// ### Exercise 2<a id="Exercise2"></a>
//
// Work out without running it whether the following method, isMonster, will return true or false when given each of the the values
//
// - "unicorn"
// - "zombie"
// - "vampire"
// - "tasmanian devil"
//
// Add three new test calls below the one that tests for it being a unicorn and then run them to see if you were right.

// %%
// Is the creature given a monster?
//
public static boolean isMonster (String monster)
{
    if ( monster.equals("zombie") || monster.equals("vampire") )
        return true;
    else
        return false;
}

// %%
// Test above method
System.out.println(isMonster("unicorn"));
// Out:
// false

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution2)

// %% [markdown]
// ### Exercise 3<a id="Exercise3"></a>
//
// When in a rush such as when zombies are coming it is easy to forget to use capitals. Modify the method below to allow either HELP or help to be typed when a zombie is seen (but nothing else) using the OR logical connective.
//
// HINT you only need to change one line and follow the format of the boolean condition from the if statement above.

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one
//
public static void zombies2 ()
{
       int count = 0;
       String answer = "HELP";
    
       while (answer.equals("HELP"))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear?");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test above method
zombies2 ();
// Out:
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear?
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear?
//  j
// You saw 2 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution3)

// %% [markdown]
// ### Exercise 4<a id="Exercise4"></a>
//
// The above method assumes we see at least one zombie as the test is set to always initialise the variable answer to "HELP". What if there may be no zombie apocalypse at all (quite likely!) We need it to be possible for the loop never to enter ie the person to start by typing something other than HELP and the count then stay at 0.
//
// This can be done by initialising the variable being tested not with a literal value but doing an input at that point (before the loop starts).
//
// In the following, change the line
//
//       String answer = "HELP";
//
// to ask instead if a zombie has been seen so that the loop could never enter. Then test the program and make sure you understand it.

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one)
// Note there could be no zombies at all!
//
public static void zombies3 ()
{
       int count = 0;
       String answer = "HELP";
    
       while ( answer.equals("HELP") || answer.equals("help"))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear?");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test above method
zombies3();
// Out:
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear?
//  h
// You saw 1 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution4)

// %% [markdown]
// ## Using Methods for loop tests ##

// %% [markdown]
// ### Exercise 5<a id="Exercise5"></a>
//
// In the following method you should type the name of a monster to trigger the warning and count. Read then compile it and run the test to make sure you understand it.
//
// However, we earlier created a method isMonster that binds into a single method the condition of whether the string given to it is a monster or not.
//
// Modify the version of the method below so that it uses isMonster as the test (so either zombies or vampires are treated as monsters) rather than using the OR connective directly itself as below. Again you only need to change one line (make sure you have compiled the definition of isMonster from Exercise 2).

// %%
// Warn of the coming monster appocalypse (Type the monsters name if you see one)
//
public static void monsters1 ()
{
       int count = 0;
       String answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
    
       while (answer.equals("zombie") || answer.equals("vampire"))
       {
           System.out.println("We've seen a monster...they are coming!");
           count = count + 1;
            
           answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " monster(s).");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test above method
monsters1();
// Out:
// Type the name of any monster you see. Type anything else if the coast is clear.
//  vampire
// We've seen a monster...they are coming!
// Type the name of any monster you see. Type anything else if the coast is clear.
//  j
// You saw 1 monster(s).
// But don't worry it was just a nightmare.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution5)

// %% [markdown]
// Binding up complex tests into a boolean method like this is a good idea as it makes the program more readable as long as we name the method well. It tells us that the test is checking for monsters.

// %% [markdown]
// ### Exercise 6<a id="Exercise6"></a>
// Write a method isCryForHelp that returns true only if given either HELP or help as argument and false otherwise by completing the method below.

// %%
// Return true if either help or HELP are given as an argument
//
public static boolean isCryForHelp (String cry)
{
    
}
// Out:
// |   {
// |
// |   }
// missing return statement
//
// |   public static boolean isCryForHelp (String cry)
// Modifier 'static' not permitted in top-level declarations, ignored

// %%
// Test above method
System.out.println( isCryForHelp("HELP") );  // should return true
System.out.println( isCryForHelp("help") );  // should return true
System.out.println( isCryForHelp("run") );  // should return false
System.out.println( isCryForHelp("Would you like a biscuit?") ); // should return false
// Out:
// |   System.out.println( isCryForHelp("HELP") );
// cannot find symbol
//   symbol:   method isCryForHelp(java.lang.String)

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution6)

// %% [markdown]
// ### Exercise 7<a id="Exercise7"></a>
//
// Now modify this version of our zombies method to use the isCryForHelp method as the test.

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one)
// Note there could be no zombies at all!
//
public static void zombies4 ()
{
       int count = 0;
       String answer = inputString("Type HELP if you've seen a Zombie. Type anything else if the coast is clear.");
    
       while (answer.equals("HELP") || answer.equals("help"))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test the above method
zombies4();
// Out:
// Type HELP if you've seen a Zombie. Type anything else if the coast is clear.
//  g
// You saw 0 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// ** Write your answer here **

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution7)

// %% [markdown]
// ## Logical And (&&) ##
//
// We can use a similar approach using a logical AND connective if we want to keep going for different reasons (or put another way, there are several reasons we might stop). One common situation is where we want a loop to be controlled both by some other stopping condition AND by a counter. We then might use the logical AND connective (&&).
//
// Also the Logical Not connective (!) is often useful, when you need a loop to keep going when some condition is not true.
//
// This gives us a way to do things like combine a counter-controlled loop with some other reason for stopping the count early as we see below. This is NOT done using two loops (as novices often assume), but with a single loop with a more complex condition having more than one reason to stop.

// %% [markdown]
// ### Exercise 8<a id="Exercise8"></a>
//
// Explain under what circumstances the following method will stop counting zombies and print the count. Run it several times to check your understanding is completely. If it does anything surprising study it more. Explain also why the if statement is needed.

// %% [markdown]
// ** Write your explanation here **

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one)
// Note there could be no zombies at all!
//
public static void zombies5 ()
{
    int count = 0;
    String answer = inputString("Type HELP if you've seen a Zombie. Type anything else if the coast is clear.");
    
    while ( isCryForHelp(answer) && (count < 3) )
    {
        System.out.println("We've seen a zombie...they are coming!");
        count = count + 1;
            
        if(count < 3)
        {
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear.");
        }
    }
       
    System.out.println("You saw " + count + " zombies.");
    System.out.println("But don't worry it was just a nightmare.");
 
    return;
}

// %%
// Test the above method
zombies5 ();
// Out:
// Type HELP if you've seen a Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// You saw 3 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution8)

// %% [markdown]
// ### Exercise 9<a id="Exercise9"></a>
//
// Modify the following monsters program so that it stops the loop either when a non-monster is typed or when the count gets to 5.
//
// HINT: Be careful the above says when the loop stops, but you formulate a loop test as when it should continue. That is the negation of the above, and negation turns logical or into logical and...

// %%
// Warn of the coming monster appocalypse (Type the monsters name if you see one)
//
public static void monsters2 ()
{
       int count = 0;
       String answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
    
       while (isMonster(answer))
       {
           System.out.println("We've seen a monster...they are coming!");
           count = count + 1;
            
           answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " monsters.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test the above method
monsters2();
// Out:
// Type the name of any monster you see. Type anything else if the coast is clear.
//  g
// You saw 0 monsters.
// But don't worry it was just a nightmare.

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution9)

// %% [markdown]
// ### Exercise 10<a id="Exercise10"></a>
//
// A dice game allows a person to repeatedly roll a dice, adding up their score. They stop whenever they wish, but if their score goes over 21 then they get 0 and the game finishes. Otherwise they get the total they achieved.
//
// Read the partial code below and make sure you follow it. Then complete the diceGame method below to play the game as above.

// %%
// Roll a 6-sided dice with sides marked 1 - 6
//
public static int rollDice ()
{
    Random dice = new Random();
    
    int dice_roll = dice.nextInt(6) + 1;
    
    return dice_roll;
}

// %%
// Play a dice game to get the highest score 
// But if you get over 21 you lose
//
public static void diceGame1 ()
{
    final int TARGET_SCORE = 21;
    int total = 0;
    String roll_again = "Y";
    
    while (  )  // TO BE COMPLETED
     {
       int dice_roll = rollDice ();
       System.out.println("You rolled a " + dice_roll);
       
       total = total + dice_roll;
       System.out.println("Your current score is " + total);

       if ( )   // TO BE COMPLETED
           roll_again = inputString("Do you wish to roll again (Y/N)?");
    }
       
    if(! (total >= TARGET_SCORE) )
    {
       total = 0;
    }
       
    System.out.println("You scored " + total);
 
    return;
}

// %%
// Test the above method
diceGame1();

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution10)

// %% [markdown]
// ### Exercise 11<a id="Exercise11"></a>
//
// **This is quite hard unless you have been actively practising decomposing programs up to this point. Take it a step at a time.**
//
// Whilst the method above may work it is quite complex and very poorly decomposed. Complete a new version decomposed into the methods as given below, by completing and testing each method based on the above program. (Note ideally you would write it as a series of methods in the first place.)
//
// HINT The new methods will call earlier methods you write to get things done.
//
// You may find it helpful to create a copy of the original method in the empty box below, then cut and paste code as you use it in the new methods, replacing the original fragment of code with a call to the new method once it has been tested.
//
// After writing each method test it and then compare it to the answer before moving on to the next method.

// %%
// You lose the game (return true) if your total exceeds the target score
//
public static boolean lostGame (int total, int TARGET_SCORE)
{

}

// %%
// Test the above method
System.out.println( lostGame(5, 21)); // Should be false
System.out.println( lostGame(21, 21)); // Should be false
System.out.println( lostGame(22, 21)); // Should be true
// Out:
// false
// false
// true

// %%
// Print final total
// If the total exceeds the target score you get 0 rather than the actual score so in that case 0 is printed
//
public static void printFinalScore (int total, int TARGET_SCORE)
{

}

// %%
// Test the above method 
printFinalScore (20, 21); // Should be 20 ie print: You scored 20
printFinalScore (21, 21); // Should be 21
printFinalScore (22, 21); // Should be 0

// %%
// Roll the dice and print what was rolled, returning the value rolled
//
public static int rollDicePrintMessage ()
{

}

// %%
// Test the above method
System.out.println( rollDicePrintMessage() ); // Should print: You rolled a x where x is whatever the dice roll was then return that number.
System.out.println( rollDicePrintMessage() );
System.out.println( rollDicePrintMessage() );
// Out:
// You rolled a 1
// 1
// You rolled a 3
// 3
// You rolled a 2
// 2

// %%
// Add the current dice roll to the score and print the score, returning the new total
//
public static int updateCurrentScore (int total, int dice_roll)
{

}

// %%
// Test the above method
System.out.println( updateCurrentScore (0, 5) ); // Should be 5 ie print: Your current score is 5    then return 5
System.out.println( updateCurrentScore (10, 6) ); // Should be 16
System.out.println( updateCurrentScore (12, 2) ); // Should be 14
// Out:
// Your current score is 5
// 5
// Your current score is 16
// 16
// Your current score is 14
// 14

// %%
// Play one round of the game given the current total
// - roll the dice and update the score, printing what rolled and the score
// - return the updated total score
//
public static int playOneRound (int total)
{

}

// %%
// Test the above method 
// answers depend on dice rolls (eg for dice rolls 4 and 6 the results would be 4 and 27)
// It should print what is rolled and the score (that given added to the roll)
System.out.println( playOneRound(0) );
System.out.println( playOneRound(21) );

// %%
// Play one game returning the total (without zeroing it if over)
//
public static int playOneGame (int TARGET_SCORE)
{

}

// %%
// Test the above method 
// Should allow to play until given target number is passed printing total.
// Should also allow to stop before that
System.out.println( playOneGame(21) );
// Out:
// You rolled a 6
// Your current score is 6
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 1
// Your current score is 7
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 4
// Your current score is 11
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 6
// Your current score is 17
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 4
// Your current score is 21
// Do you wish to roll again (Y/N)?
//  N
// 21

// %%
// Play a dice game to get the highest score 
// But if you get over 21 you lose getting 0
//
public static void diceGame2 ()
{

}

// %%
// Test the above method
diceGame2 ();

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution11)

// %% [markdown]
// ### Exercise 12<a id="Exercise12"></a>

// %% [markdown]
// Summarise the key points about using logical connectives in the tests of while loops.

// %% [markdown]
// **Write your answer here**

// %% [markdown]
// **NOW READ THE ANSWER** [Click here to jump to the solution to this exercise](#Solution12)

// %% [markdown]
// *Once you have done the above exercises (and understand how the concepts work) move on to doing the actual programming exercises from the handbook, writing full programs. You must be able to write full programs, not just fragments.*

// %% [markdown]
// ## Solutions
//
// ### Solution to Exercise 1<a id="Solution1"></a>

// %% [markdown]
// The method zombies1 prints:
//
// We've seen a zombie...they are coming!
//
// and then asks the person to type in HELP to continue looking for zombies.
//
// It then does this as many times as they type HELP. If they type anything else but HELP, then the program stops.
//
// Once the loop ends, it prints how many times zombies were printed as seen (which is one more than the number of times HELP is typed). This count is kept in a counter variable. Finally, it prints that it was all a nightmare.
//
// Note the loop is NOT a counter-controlled loop even though it keeps a counter, as the counter does **not** determine how many times the loop executes.

// %% [markdown]
// [Return to Exercise](#Exercise1)

// %% [markdown]
// ### Solution to Exercise 2<a id="Solution2"></a>

// %% [markdown]
// It returns the following values:
//
// - "unicorn": false
// - "zombie" : true
// - "vampire" : true
// - "tasmanian devil" : false
//
// as it returns true only if the string passed is either "zombie" or "vampire".
//
// The following tests show this.

// %%
// Test above method
System.out.println(isMonster("unicorn"));  // should return false
System.out.println(isMonster("zombie"));  // should return true
System.out.println(isMonster("vampire"));  // should return true
System.out.println(isMonster("tasmanian devil"));  // should return false
// Out:
// false
// true
// true
// false

// %% [markdown]
// [Return to Exercise](#Exercise2)

// %% [markdown]
// ### Solution to Exercise 3<a id="Solution3"></a>

// %% [markdown]
// You just need to extend the test using the OR connective.

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one
//
public static void zombies2 ()
{
       int count = 0;
       String answer = "HELP";
    
       while (answer.equals("HELP") || answer.equals("help"))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test above method
zombies2();
// Out:
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  help
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  help
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  j
// You saw 4 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// [Return to Exercise](#Exercise3)

// %% [markdown]
// ### Solution to Exercise 4<a id="Solution4"></a>

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one)
// Note there could be no zombies at all!
//
public static void zombies3 ()
{
       int count = 0;
       String answer = inputString("Type HELP if you've seen a Zombie. Type anything else if the coast is clear.");
    
       while (answer.equals("HELP"))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test above method
zombies3 ();
// Out:
// Type HELP if you've seen a Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  help
// You saw 1 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// [Return to Exercise](#Exercise4)

// %% [markdown]
// ### Solution to Exercise 5<a id="Solution5"></a>
//
// Note that in this method the possible monster is stored in a variable called answer so we ask if answer is a monster using the call isMonster(answer)

// %%
// Warn of the coming monster appocalypse (Type the monsters name if you see one)
//
public static void monsters1 ()
{
       int count = 0;
       String answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
    
       while (isMonster(answer))
       {
           System.out.println("We've seen a monster...they are coming!");
           count = count + 1;
            
           answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " monster(s).");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test above method
monsters1();
// Out:
// Type the name of any monster you see. Type anything else if the coast is clear.
//  vampire
// We've seen a monster...they are coming!
// Type the name of any monster you see. Type anything else if the coast is clear.
//  d
// You saw 1 monster(s).
// But don't worry it was just a nightmare.

// %% [markdown]
// [Return to Exercise](#Exercise5)

// %% [markdown]
// ### Solution to Exercise 6<a id="Solution6"></a>

// %%
// Return true if either help or HELP are given as an argument
//
public static boolean isCryForHelp (String cry)
{
    if (cry.equals("HELP") || cry.equals("help") )
        return true;
    else
        return false;
}

// %%
// Test above method
System.out.println( isCryForHelp("HELP") );  // should return true
System.out.println( isCryForHelp("help") ); // should return true
System.out.println( isCryForHelp("run") ); // should return false
System.out.println( isCryForHelp("Would you like a biscuit?") ); // should return false
// Out:
// true
// true
// false
// false

// %% [markdown]
// [Return to Exercise](#Exercise6)

// %% [markdown]
// ### Solution to Exercise 7<a id="Solution7"></a>

// %%
// Warn of the coming zombie appocalypse (Type HELP or help if you see one)
// Note there could be no zombies at all!
//
public static void zombies4 ()
{
       int count = 0;
       String answer = inputString("Type HELP if you've seen a Zombie. Type anything else if the coast is clear.");
    
       while (isCryForHelp(answer))
       {
           System.out.println("We've seen a zombie...they are coming!");
           count = count + 1;
            
           answer = inputString("Type HELP if you've seen another Zombie. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " zombies.");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test the above method
zombies4 ();
// Out:
// Type HELP if you've seen a Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  HELP
// We've seen a zombie...they are coming!
// Type HELP if you've seen another Zombie. Type anything else if the coast is clear.
//  h
// You saw 2 zombies.
// But don't worry it was just a nightmare.

// %% [markdown]
// [Return to Exercise](#Exercise7)

// %% [markdown]
// ### Solution to Exercise 8<a id="Solution8"></a>

// %% [markdown]
// The test is
//
//  isCryForHelp(answer) && (count < 3)
//
//  This means the loop will keep going as long as BOTH
//
//  - a cry for help is given (eg HELP is typed when asked) AND
//  - the count is less than 3.
//
// The loop will stop therefore if one or the other of these conditions is false. It will stop if the answer was not a cry for help. However, it will also stop if the count becomes greater than or equal to 3.
//
// It will therefore exit the loop and print the count once it gets to 3 or if the person types something other than a cry for help earlier. (So 3 is the highest the count will ever get to and the loop will never execute more than 3 times).
//
// The if statement is needed because before we ask again for the next input from the user we need to be sure we haven't reached the count already - as we only want to ask again if we aren't at the count and so need to stop whatever. However, the while loop test will not actually test the count until we finish the body and jump to the top. So we check whether we need to ask again before we do ask. Notice it is only a single branch if statement as we do nothing extra if the count is reached. Then we just want to continue to the loop test and be released from the loop.

// %% [markdown]
// [Return to Exercise](#Exercise8)

// %% [markdown]
// ### Solution to Exercise 9<a id="Solution9"></a>

// %%
// Warn of the coming monster appocalypse (Type the monsters name if you see one)
//
public static void monsters2 ()
{
       int count = 0;
       String answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
    
       while (isMonster(answer) && (count < 5))
       {
           System.out.println("We've seen a monster...they are coming!");
           count = count + 1;
            
           if (count < 5)
               answer = inputString("Type the name of any monster you see. Type anything else if the coast is clear.");
       }
       
       System.out.println("You saw " + count + " monster(s).");
       System.out.println("But don't worry it was just a nightmare.");
 
       return;
}

// %%
// Test the above method
monsters2 ();
// Out:
// Type the name of any monster you see. Type anything else if the coast is clear.
//  vampire
// We've seen a monster...they are coming!
// Type the name of any monster you see. Type anything else if the coast is clear.
//  vampire
// We've seen a monster...they are coming!
// Type the name of any monster you see. Type anything else if the coast is clear.
//  vampire
// We've seen a monster...they are coming!
// Type the name of any monster you see. Type anything else if the coast is clear.
//  zombie
// We've seen a monster...they are coming!
// Type the name of any monster you see. Type anything else if the coast is clear.
//  zombie
// We've seen a monster...they are coming!
// You saw 5 monster(s).
// But don't worry it was just a nightmare.

// %% [markdown]
// [Return to Exercise](#Exercise9)

// %% [markdown]
// ### Solution to Exercise 10<a id="Solution10"></a>

// %%
// Play a dice game to get the highest score.
// But if you get over 21 you lose
//
public static void diceGame1 ()
{
    final int TARGET_SCORE = 21;
    int total = 0;
    String roll_again = "Y";
    
    while (roll_again.equals("Y") && ! (total > TARGET_SCORE))
    {
       int dice_roll = rollDice();
       System.out.println("You rolled a " + dice_roll);
      
       total = total + dice_roll;
       System.out.println("Your current score is " + total);

       if ( (total <= TARGET_SCORE) )
           roll_again = inputString("Do you wish to roll again (Y/N)?");
    }
       
    if( (total > TARGET_SCORE) )
    {
       total = 0;
    }
       
    System.out.println("You scored " + total);
 
    return;
}

// %%
// Test the above method
diceGame1();
// Out:
// You rolled a 3
// Your current score is 3
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 3
// Your current score is 6
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 4
// Your current score is 10
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 2
// Your current score is 12
// Do you wish to roll again (Y/N)?
//  Y
// You rolled a 2
// Your current score is 14
// Do you wish to roll again (Y/N)?
//  N
// You scored 14

// %% [markdown]
// [Return to Exercise](#Exercise10)

// %% [markdown]
// ### Solution to Exercise 11<a id="Solution11"></a>

// %% [markdown]
// The following method is equivalent to a version with an if statement as it if the boolean condition is true it returns true and if it is false it returns false.

// %%
// You lose the game if your total exceeds the target score
//
public static boolean lostGame (int total, int TARGET_SCORE)
{
    return (total > TARGET_SCORE);
}

// %%
// Test the above method
System.out.println( lostGame(5, 21)); // Should be false
System.out.println( lostGame(21, 21)); // Should be false
System.out.println( lostGame(22, 21)); // Should be true
// Out:
// false
// false
// true

// %%
// Print final total
// If the total exceeds the target score, however you get 0
//
public static void printFinalScore (int total, int TARGET_SCORE)
{
    if( lostGame(total, TARGET_SCORE) )
    {
       total = 0;
    }
       
    System.out.println("You scored " + total);
    
    return;
}

// %%
// Test the above method 
printFinalScore (20, 21); // Should be 20
printFinalScore (21, 21); // Should be 21
printFinalScore (22, 21); // Should be 0
// Out:
// You scored 20
// You scored 21
// You scored 0

// %%
// Roll the dice and print what was rolled, returning the value rolled
//
public static int rollDicePrintMessage ()
{
    int dice_roll = rollDice ();
    System.out.println("You rolled a " + dice_roll);
    
    return dice_roll;
}

// %%
// Test the above method
System.out.println( rollDicePrintMessage() );
System.out.println( rollDicePrintMessage() );
System.out.println( rollDicePrintMessage() );
// Out:
// You rolled a 1
// 1
// You rolled a 3
// 3
// You rolled a 2
// 2

// %%
// Add the current dice roll to the score and print the score, returning the new total
//
public static int updateCurrentScore (int total, int dice_roll)
{
    total = total + dice_roll;
    System.out.println("Your current score is " + total);
    
    return total;
}

// %%
// Test the above method
System.out.println( updateCurrentScore (0, 5) ); // Should be 5
System.out.println( updateCurrentScore (10, 6) ); // Should be 16
System.out.println( updateCurrentScore (12, 2) ); // Should be 14
// Out:
// Your current score is 5
// 5
// Your current score is 16
// 16
// Your current score is 14
// 14

// %%
// Play one round of the game given the current total
// - roll the dice and update the score, printing what rolled and the score
// - return the updated total score
//
public static int playOneRound (int total)
{
    int dice_roll = rollDicePrintMessage ();
       
    total = updateCurrentScore (total, dice_roll);
    
    return total;
}

// %%
// Test the above method 
// answers depend on dice rolls (eg for dice rolls 4 and 6 the results would be 4 and 27)
// It should print what is rolled and the score (that given added to the roll
System.out.println( playOneRound(0) );
System.out.println( playOneRound(21) );
// Out:
// You rolled a 2
// Your current score is 2
// 2
// You rolled a 5
// Your current score is 26
// 26

// %%
// Play one game returning the total (without zeroing it if over)
//
public static int playOneGame (int TARGET_SCORE)
{
    int total = 0;
    String roll_again = "Y";
    
    while (roll_again.equals("Y") && ! lostGame(total, TARGET_SCORE) )
    {
       total = playOneRound (total);
        
       if ( ! lostGame(total, TARGET_SCORE) )
           roll_again = inputString("Do you wish to roll again (Y/N)?");
    }
     
    return total;
}

// %%
// Test the above method 
// Should allow to play until given target number is passed printing total.
// Should also allow to stop before that
System.out.println( playOneGame(21) );
// Out:
// You rolled a 6
// Your current score is 6
// Do you wish to roll again (Y/N)?

// %%
// Play a dice game to get the highest score 
// But if you get over 21 you lose getting 0
//
public static void diceGame2 ()
{
    final int TARGET_SCORE = 21;
    
    int total = playOneGame (TARGET_SCORE);    
    printFinalScore (total, TARGET_SCORE);
 
    return;
}

// %%
// Test the above method
diceGame2 ();

// %% [markdown]
// [Return to Exercise](#Exercise11)

// %% [markdown]
// ### Solution to Exercise 12<a id="Solution12"></a>

// %% [markdown]
// A While loop test can be made more complex by using logical connectives.
//
// Logical or (||) allows you to combine two different conditions so that the loop keeps going if any of them are true. This is useful for example, when there are various different conditions, any of which are a reason to continue in the loop. As we saw various related input possibilities that would mean "keep going" are one example.
//
// Logical and (&&) is useful when there are a series of conditions, all of which must hold to continue (so the negation of each is a stopping condition). This is useful for example when combining a counter controlled loop with some other earlier stopping condition.
//
// With multiple stopping conditions care has to be taken that unnecessary computation isn't done after one has become true. This can be an issue because the loop exit condition is only tested when we get to the end of the body and start a new iteration.
//
// It is often good to embed test conditions in methods with names that indicate what the test means (such as hasLost(...)). This, as with any well defined decomposition, makes the code more readable and easier to understand. That method can also then be tested separately.

// %% [markdown]
// [Return to Exercise](#Exercise12)
